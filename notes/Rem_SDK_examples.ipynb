# %%
# %load_ext autoreload
# %autoreload 2
import remo

# %% [markdown]
# TODO: Remove need to login

# %%
sdk = remo.SDK('https://remo.ai', 'email_address', 'password')

# %% [markdown]
# ### List datasets

# %%
my_datasets = sdk.list_datasets()
my_datasets
# Out:
# [{'id': 3, 'name': 'Open Images V5', 'license_id': None},
#  {'id': 4, 'name': 'Multi folders 3', 'license_id': None},
#  {'id': 6, 'name': 'Open Images Dataset V5', 'license_id': None},
#  {'id': 7, 'name': 'test andra', 'license_id': None},
#  {'id': 14, 'name': 'Imagenette', 'license_id': None},
#  {'id': 15, 'name': 'Andrea Test 2', 'license_id': None},
#  {'id': 17, 'name': 'Images', 'license_id': None},
#  {'id': 18, 'name': 'Im', 'license_id': None},
#  {'id': 19, 'name': 'asim', 'license_id': None},
#  {'id': 35, 'name': 'Open Images V5', 'license_id': None},
#  {'id': 36, 'name': 'COCO 2', 'license_id': None},
#  {'id': 37, 'name': 'Multi folders 3', 'license_id': None},
#  {'id': 61, 'name': 'Andrea Test2', 'license_id': None},
#  {'id': 64, 'name': 'Sample', 'license_id': None},
#  {'id': 65, 'name': 'LargeOne', 'license_id': None},
#  {'id': 70, 'name': 'Demo: imagenet', 'license_id': None},
#  {'id': 75, 'name': 'dataset test: imagenet', 'license_id': None},
#  {'id': 76, 'name': 'dataset test: imagenet', 'license_id': None},
#  {'id': 77, 'name': 'Hello world', 'license_id': None},
#  {'id': 78, 'name': 'Melodi', 'license_id': None},
#  {'id': 79, 'name': 'Animals', 'license_id': None},
#  {'id': 80, 'name': 'dataset test: imagenet4', 'license_id': None}]

# %% [markdown]
# ### Get a dataset

# %% [markdown]
# we need to edit the output of typing 'my_dataset'

# %%
my_dataset = sdk.get_dataset(78)
my_dataset
# Out:
# Next: None
# dog3.jpg Melodi
# dog2.jpg Melodi
# dog1.jpg Melodi
# Dataset 78 - 'Melodi'

# %% [markdown]
# ### Create dataset

# %%
dataset = sdk.create_dataset(name = 'dataset test: imagenet',
                            urls=["https://remo-sample-datasets.s3-eu-west-1.amazonaws.com/Imagenet_sample_dataset.zip"],
                            annotation_task=remo.AnnotationTask.image_classification)
dataset
# Out:
# {'id': 31, 'annotation_sets': [], 'total_classes': 0, 'license': None, 'top3_classes': [], 'is_public': False, 'name': 'dataset test: imagenet', 'users_shared': [], 'total_annotation_objects': 0, 'created_at': '2019-10-04T16:08:24.085438Z'}
# {'jobs': [{'job_id': 'e5557c74-4309-4308-b1c2-777355084a7f', 'status': 'queued'}]}
# Dataset 31 - 'dataset test: imagenet'

# %% [markdown]
# ### Dataset browse

# %%
dataset.browse()
# Out:
# Open https://remo.ai/datasets/31

# %% [markdown]
# ### Add data to your dataset

# %%
sdk.add_data_to_dataset(7, urls=["https://remo-sample-datasets.s3-eu-west-1.amazonaws.com/Imagenet_sample_dataset.zip"],
               annotation_task=remo.AnnotationTask.image_classification)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-0af69caecbb6> in <module>()
#       1 sdk.add_data_to_dataset(7, urls=["https://remo-sample-datasets.s3-eu-west-1.amazonaws.com/Imagenet_sample_dataset.zip"],
# ----> 2                annotation_task=remo.AnnotationTask.image_classification)
#
# ~\Desktop\Projects\repo\rem_repo\remo-python\remo\sdk.py in add_data_to_dataset(self, dataset_id, files, urls, annotation_task, folder_id)
#      69             result['files_upload_result'] = files_upload_result
#      70         if len(urls):
# ---> 71             urls_upload_result = self.api.upload_urls(dataset_id, urls, annotation_task, folder_id)
#      72             print(urls_upload_result)
#      73             result['urls_upload_result'] = urls_upload_result
#
# ~\Desktop\Projects\repo\rem_repo\remo-python\remo\api.py in upload_urls(self, dataset_id, urls, annotation_task, folder_id)
#     144
#     145         url = self.url('/api/dataset/{}/upload'.format(dataset_id))
# --> 146         return self.post(url, json=payload).json()
#     147
#     148     def list_annotation_sets(self, dataset_id):
#
# ~\AppData\Local\Continuum\anaconda3\envs\py35_2\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~\AppData\Local\Continuum\anaconda3\envs\py35_2\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\envs\py35_2\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\envs\py35_2\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
dataset.browse()
# Out:
# Open https://dev.remo.ai/datasets/74

# %% [markdown]
# ### TBC - Annotation statistics

# %%
my_dataset = sdk.get_dataset(78)
# Out:
# Next: None
# dog3.jpg Melodi
# dog2.jpg Melodi
# dog1.jpg Melodi

# %%
sdk.ann_statistics(78)
# Out:
# [{'id': 51,
#   'annotation_set_id': 99,
#   'classes': "{'Dog': {'n_imgs': 3, 'n_objs': 3}}",
#   'tags': '[]',
#   'top3_classes': "[[3, 'Dog']]",
#   'total_classses': 1,
#   'total_annotated_images': 3,
#   'total_annotation_objects': 3}]

# %% [markdown]
# ### Get annotations

# %%
sdk.list_annotation_sets(6)
# Out:
# [{'id': 1,
#   'classes': "['Tree']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Tree'], 'coordinates': [{'x': 73.6, 'y': 158.39999999999998}, {'x': 148.8, 'y': 300.80001024}]}, {'name': 'OBJ1', 'classes': ['Tree'], 'coordinates': [{'x': 449.6, 'y': 203.19998976}, {'x': 585.6, 'y': 334.40000256}]}, {'name': 'OBJ2', 'classes': ['Tree'], 'coordinates': [{'x': 684.8, 'y': 0.0}, {'x': 1024.0, 'y': 423.99997440000004}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 525107},
#  {'id': 2,
#   'classes': "['Chicken', 'Plant']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Plant'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1024.0, 'y': 768.0}]}, {'name': 'OBJ1', 'classes': ['Chicken'], 'coordinates': [{'x': 177.6, 'y': 152.00000255999998}, {'x': 480.0, 'y': 608.0000256}]}, {'name': 'OBJ2', 'classes': ['Chicken'], 'coordinates': [{'x': 460.8, 'y': 199.99999488000003}, {'x': 702.4, 'y': 423.99997440000004}]}, {'name': 'OBJ3', 'classes': ['Chicken'], 'coordinates': [{'x': 955.2, 'y': 307.20000000000005}, {'x': 1024.0, 'y': 495.99997440000004}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 517395},
#  {'id': 19781,
#   'classes': "['Bread', 'Pastry', 'Snack', 'Dessert']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Snack'], 'coordinates': [{'x': 53.248, 'y': 365.671779}, {'x': 207.872, 'y': 511.121226}]}, {'name': 'OBJ1', 'classes': ['Snack'], 'coordinates': [{'x': 125.952, 'y': 318.554577}, {'x': 246.784, 'y': 370.79351099999997}]}, {'name': 'OBJ2', 'classes': ['Snack'], 'coordinates': [{'x': 166.912, 'y': 522.3885809999999}, {'x': 259.072, 'y': 558.239187}]}, {'name': 'OBJ3', 'classes': ['Snack'], 'coordinates': [{'x': 183.296, 'y': 373.86670200000003}, {'x': 317.44, 'y': 457.85840099999996}]}, {'name': 'OBJ4', 'classes': ['Snack'], 'coordinates': [{'x': 211.968, 'y': 546.971832}, {'x': 276.48, 'y': 586.918761}]}, {'name': 'OBJ5', 'classes': ['Snack'], 'coordinates': [{'x': 233.472, 'y': 557.214537}, {'x': 314.368, 'y': 610.477362}]}, {'name': 'OBJ6', 'classes': ['Snack'], 'coordinates': [{'x': 261.12, 'y': 557.214537}, {'x': 347.136, 'y': 642.2308859999999}]}, {'name': 'OBJ7', 'classes': ['Snack'], 'coordinates': [{'x': 282.624, 'y': 119.84230500000001}, {'x': 768.0, 'y': 221.24698199999997}]}, {'name': 'OBJ8', 'classes': ['Snack'], 'coordinates': [{'x': 291.84, 'y': 640.1823449999999}, {'x': 402.432, 'y': 694.46982}]}, {'name': 'OBJ9', 'classes': ['Snack'], 'coordinates': [{'x': 309.248, 'y': 314.457495}, {'x': 401.408, 'y': 381.036216}]}, {'name': 'OBJ10', 'classes': ['Snack'], 'coordinates': [{'x': 322.56, 'y': 429.17806799999994}, {'x': 533.504, 'y': 520.3400399999999}]}, {'name': 'OBJ11', 'classes': ['Snack'], 'coordinates': [{'x': 391.168, 'y': 335.967555}, {'x': 536.576, 'y': 407.66800800000004}]}, {'name': 'OBJ12', 'classes': ['Snack'], 'coordinates': [{'x': 476.16, 'y': 600.2346570000001}, {'x': 590.848, 'y': 658.619214}]}, {'name': 'OBJ13', 'classes': ['Snack'], 'coordinates': [{'x': 519.168, 'y': 465.02867399999997}, {'x': 616.448, 'y': 525.461772}]}, {'name': 'OBJ14', 'classes': ['Snack'], 'coordinates': [{'x': 548.864, 'y': 362.599347}, {'x': 719.872, 'y': 450.688128}]}, {'name': 'OBJ15', 'classes': ['Snack'], 'coordinates': [{'x': 605.184, 'y': 581.797788}, {'x': 670.72, 'y': 629.93964}]}, {'name': 'OBJ16', 'classes': ['Snack'], 'coordinates': [{'x': 630.784, 'y': 598.1861160000001}, {'x': 728.064, 'y': 649.401159}]}, {'name': 'OBJ17', 'classes': ['Dessert'], 'coordinates': [{'x': 40.96, 'y': 356.453724}, {'x': 244.736, 'y': 509.072685}]}, {'name': 'OBJ18', 'classes': ['Dessert'], 'coordinates': [{'x': 115.712, 'y': 291.922785}, {'x': 283.648, 'y': 367.72032}]}, {'name': 'OBJ19', 'classes': ['Dessert'], 'coordinates': [{'x': 139.264, 'y': 350.307342}, {'x': 276.48, 'y': 407.66800800000004}]}, {'name': 'OBJ20', 'classes': ['Dessert'], 'coordinates': [{'x': 148.48, 'y': 203.83400400000002}, {'x': 188.416, 'y': 235.58676899999998}]}, {'name': 'OBJ21', 'classes': ['Dessert'], 'coordinates': [{'x': 159.744, 'y': 513.169767}, {'x': 406.528, 'y': 682.177815}]}, {'name': 'OBJ22', 'classes': ['Dessert'], 'coordinates': [{'x': 179.2, 'y': 368.74496999999997}, {'x': 323.584, 'y': 456.833751}]}, {'name': 'OBJ23', 'classes': ['Dessert'], 'coordinates': [{'x': 219.136, 'y': 205.88254500000002}, {'x': 258.048, 'y': 240.708501}]}, {'name': 'OBJ24', 'classes': ['Dessert'], 'coordinates': [{'x': 270.336, 'y': 123.939387}, {'x': 778.24, 'y': 197.688381}]}, {'name': 'OBJ25', 'classes': ['Dessert'], 'coordinates': [{'x': 307.2, 'y': 310.360413}, {'x': 417.792, 'y': 386.157948}]}, {'name': 'OBJ26', 'classes': ['Dessert'], 'coordinates': [{'x': 312.32, 'y': 234.56287799999998}, {'x': 530.432, 'y': 309.335763}]}, {'name': 'OBJ27', 'classes': ['Dessert'], 'coordinates': [{'x': 320.512, 'y': 422.007795}, {'x': 544.768, 'y': 539.801559}]}, {'name': 'OBJ28', 'classes': ['Dessert'], 'coordinates': [{'x': 382.976, 'y': 319.579227}, {'x': 537.6, 'y': 406.643358}]}, {'name': 'OBJ29', 'classes': ['Dessert'], 'coordinates': [{'x': 479.232, 'y': 594.089034}, {'x': 589.824, 'y': 661.692405}]}, {'name': 'OBJ30', 'classes': ['Dessert'], 'coordinates': [{'x': 547.84, 'y': 369.76886099999996}, {'x': 713.728 ...
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 384871},
#  {'id': 11602,
#   'classes': "['Car', 'Mammal', 'Human arm', 'Human leg', 'Tree', 'Footwear', 'Person', 'Clothing', 'Sports equipment', 'Man', 'Ball', 'Jeans', 'Human body']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human leg'], 'coordinates': [{'x': 93.64012032, 'y': 349.05532551}, {'x': 172.17698816, 'y': 580.2477725}]}, {'name': 'OBJ1', 'classes': ['Human leg'], 'coordinates': [{'x': 123.846610944, 'y': 349.05532551}, {'x': 262.79645184, 'y': 636.1570597}]}, {'name': 'OBJ2', 'classes': ['Human leg'], 'coordinates': [{'x': 285.45132544, 'y': 265.94690882}, {'x': 351.90560768, 'y': 429.1416038}]}, {'name': 'OBJ3', 'classes': ['Human leg'], 'coordinates': [{'x': 329.25073408, 'y': 293.14601782}, {'x': 376.07079936, 'y': 392.87610692}]}, {'name': 'OBJ4', 'classes': ['Human leg'], 'coordinates': [{'x': 673.6047104, 'y': 323.36725156}, {'x': 691.72864, 'y': 397.4092872}]}, {'name': 'OBJ5', 'classes': ['Human leg'], 'coordinates': [{'x': 694.7492864, 'y': 323.36725156}, {'x': 720.4248064, 'y': 391.36503772}]}, {'name': 'OBJ6', 'classes': ['Human leg'], 'coordinates': [{'x': 839.740416, 'y': 323.36725156}, {'x': 1017.9587072, 'y': 542.4712473999999}]}, {'name': 'OBJ7', 'classes': ['Human leg'], 'coordinates': [{'x': 918.27728384, 'y': 317.32300208}, {'x': 1024.0, 'y': 506.20575052}]}, {'name': 'OBJ8', 'classes': ['Car'], 'coordinates': [{'x': 252.22418432, 'y': 173.77212474}, {'x': 296.02359296, 'y': 213.0597327}]}, {'name': 'OBJ9', 'classes': ['Car'], 'coordinates': [{'x': 441.01474304, 'y': 170.75}, {'x': 524.0825856, 'y': 205.50442768}]}, {'name': 'OBJ10', 'classes': ['Car'], 'coordinates': [{'x': 475.75220224, 'y': 176.79424948}, {'x': 508.97934336, 'y': 219.10398218}]}, {'name': 'OBJ11', 'classes': ['Car'], 'coordinates': [{'x': 508.97934336, 'y': 176.79424948}, {'x': 637.3569536, 'y': 229.68141194}]}, {'name': 'OBJ12', 'classes': ['Car'], 'coordinates': [{'x': 664.54278144, 'y': 190.39380398}, {'x': 741.5693312, 'y': 264.43583962}]}, {'name': 'OBJ13', 'classes': ['Jeans'], 'coordinates': [{'x': 89.1091456, 'y': 341.5}, {'x': 223.52802816, 'y': 619.53539412}]}, {'name': 'OBJ14', 'classes': ['Jeans'], 'coordinates': [{'x': 286.96164352, 'y': 253.85840986}, {'x': 356.4365824, 'y': 415.5420493}]}, {'name': 'OBJ15', 'classes': ['Jeans'], 'coordinates': [{'x': 862.3952896, 'y': 306.74557232}, {'x': 1024.0, 'y': 542.4712473999999}]}, {'name': 'OBJ16', 'classes': ['Person'], 'coordinates': [{'x': 666.05312, 'y': 234.21460588}, {'x': 723.4454528, 'y': 395.898218}]}, {'name': 'OBJ17', 'classes': ['Clothing'], 'coordinates': [{'x': 74.005897216, 'y': 151.10619602}, {'x': 276.389376, 'y': 621.0464633199999}]}, {'name': 'OBJ18', 'classes': ['Clothing'], 'coordinates': [{'x': 286.96164352, 'y': 194.92699792000002}, {'x': 376.07079936, 'y': 415.5420493}]}, {'name': 'OBJ19', 'classes': ['Clothing'], 'coordinates': [{'x': 667.5634176, 'y': 258.39159014}, {'x': 718.9144576, 'y': 359.6327621}]}, {'name': 'OBJ20', 'classes': ['Clothing'], 'coordinates': [{'x': 862.3952896, 'y': 213.0597327}, {'x': 1024.0, 'y': 542.4712473999999}]}, {'name': 'OBJ21', 'classes': ['Human body'], 'coordinates': [{'x': 72.49557504, 'y': 86.13052777}, {'x': 332.27139072, 'y': 651.2677175499999}]}, {'name': 'OBJ22', 'classes': ['Human body'], 'coordinates': [{'x': 75.516227584, 'y': 96.70796436}, {'x': 285.45132544, 'y': 636.1570597}]}, {'name': 'OBJ23', 'classes': ['Human body'], 'coordinates': [{'x': 274.87905792, 'y': 167.72787526000002}, {'x': 406.27728384, 'y': 445.7632967}]}, {'name': 'OBJ24', 'classes': ['Human body'], 'coordinates': [{'x': 650.9498368, 'y': 220.61503772}, {'x': 729.4867456, 'y': 409.4977725}]}, {'name': 'OBJ25', 'classes': ['Human body'], 'coordinates': [{'x': 666.05312, 'y': 232.70353667999998}, {'x': 723.4454528, 'y': 397.4092872}]}, {'name': 'OBJ26', 'classes': ['Human body'], 'coordinates': [{'x': 830.67846656, 'y': 188.88274844}, {'x': 1024.0, 'y': 543.9822824500001}]}, {'name': 'OBJ27', 'classes': ['Ball'], 'coordinates': [{'x': 561.84070144, 'y': 364.16592872}, {'x': 604.129792, 'y': 403.45353668}]}, {'name': 'OBJ28', 'classes': ['Mammal'], 'coordinates': [{'x': 77.02654976, 'y': 95.19690199}, {' ...
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 525727},
#  {'id': 281,
#   'classes': "['Mammal', 'Tree', 'Person', 'Plant', 'Ball']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Plant'], 'coordinates': [{'x': 433.6, 'y': 137.59999488}, {'x': 571.2, 'y': 208.00000511999997}]}, {'name': 'OBJ1', 'classes': ['Plant'], 'coordinates': [{'x': 540.8, 'y': 153.60000000000002}, {'x': 644.8, 'y': 209.60000255999998}]}, {'name': 'OBJ2', 'classes': ['Plant'], 'coordinates': [{'x': 640.0, 'y': 137.59999488}, {'x': 726.4, 'y': 209.60000255999998}]}, {'name': 'OBJ3', 'classes': ['Plant'], 'coordinates': [{'x': 835.2, 'y': 128.00000255999998}, {'x': 896.0, 'y': 206.39999999999998}]}, {'name': 'OBJ4', 'classes': ['Plant'], 'coordinates': [{'x': 878.4, 'y': 179.19999744}, {'x': 912.0, 'y': 222.39999744000002}]}, {'name': 'OBJ5', 'classes': ['Plant'], 'coordinates': [{'x': 908.8, 'y': 59.200000512}, {'x': 1022.4, 'y': 247.99999488000003}]}, {'name': 'OBJ6', 'classes': ['Plant'], 'coordinates': [{'x': 961.6, 'y': 147.19999488}, {'x': 1022.4, 'y': 270.39999744}]}, {'name': 'OBJ7', 'classes': ['Person'], 'coordinates': [{'x': 232.0, 'y': 153.60000000000002}, {'x': 302.4, 'y': 332.80000512000004}]}, {'name': 'OBJ8', 'classes': ['Person'], 'coordinates': [{'x': 235.2, 'y': 20.800000512}, {'x': 300.8, 'y': 204.80001024}]}, {'name': 'OBJ9', 'classes': ['Person'], 'coordinates': [{'x': 452.8, 'y': 27.199999488}, {'x': 524.8, 'y': 228.80001024}]}, {'name': 'OBJ10', 'classes': ['Person'], 'coordinates': [{'x': 753.6, 'y': 11.199999744}, {'x': 857.6, 'y': 295.99999488000003}]}, {'name': 'OBJ11', 'classes': ['Ball'], 'coordinates': [{'x': 0.0, 'y': 512.0000256}, {'x': 203.2, 'y': 723.19999488}]}, {'name': 'OBJ12', 'classes': ['Mammal'], 'coordinates': [{'x': 227.2, 'y': 153.60000000000002}, {'x': 296.0, 'y': 336.0}]}, {'name': 'OBJ13', 'classes': ['Mammal'], 'coordinates': [{'x': 230.4, 'y': 22.400000256}, {'x': 294.4, 'y': 204.80001024}]}, {'name': 'OBJ14', 'classes': ['Mammal'], 'coordinates': [{'x': 456.0, 'y': 28.799999999999997}, {'x': 520.0, 'y': 222.39999744000002}]}, {'name': 'OBJ15', 'classes': ['Mammal'], 'coordinates': [{'x': 763.2, 'y': 11.199999744}, {'x': 857.6, 'y': 291.19999487999996}]}, {'name': 'OBJ16', 'classes': ['Tree'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1022.4, 'y': 190.40000256000002}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 538638},
#  {'id': 807,
#   'classes': "['Building']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Building'], 'coordinates': [{'x': 16.0, 'y': 0.0}, {'x': 1024.0, 'y': 639.9999744}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 519526},
#  {'id': 1009,
#   'classes': "['Tree', 'Human face', 'Human head', 'Flower', 'Human nose', 'Clothing']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human face'], 'coordinates': [{'x': 587.7833728, 'y': 256.92419072}, {'x': 674.65704448, 'y': 330.85919232}]}, {'name': 'OBJ1', 'classes': ['Human nose'], 'coordinates': [{'x': 633.9928064, 'y': 292.04333568}, {'x': 654.3248896, 'y': 327.16244992}]}, {'name': 'OBJ2', 'classes': ['Clothing'], 'coordinates': [{'x': 417.73285376, 'y': 395.55233792}, {'x': 866.8880896, 'y': 1024.0}]}, {'name': 'OBJ3', 'classes': ['Human head'], 'coordinates': [{'x': 547.11914496, 'y': 131.23465216}, {'x': 763.3790976, 'y': 473.18411264}]}, {'name': 'OBJ4', 'classes': ['Flower'], 'coordinates': [{'x': 0.0, 'y': 304.9819648}, {'x': 1024.0, 'y': 1024.0}]}, {'name': 'OBJ5', 'classes': ['Tree'], 'coordinates': [{'x': 0.0, 'y': 85.02526976}, {'x': 1024.0, 'y': 406.64260608}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 515453},
#  {'id': 1187,
#   'classes': "['Weapon', 'Toy']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Weapon'], 'coordinates': [{'x': 164.8, 'y': 68.79999744}, {'x': 643.2, 'y': 632.0000256}]}, {'name': 'OBJ1', 'classes': ['Toy'], 'coordinates': [{'x': 166.4, 'y': 17.600000256}, {'x': 1024.0, 'y': 766.39997952}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 515906},
#  {'id': 1418,
#   'classes': "['Tree', 'Building', 'Flower', 'Plant']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Plant'], 'coordinates': [{'x': 20.800000512, 'y': 590.4}, {'x': 222.39999744000002, 'y': 788.8}]}, {'name': 'OBJ1', 'classes': ['Plant'], 'coordinates': [{'x': 164.80000512, 'y': 380.8}, {'x': 768.0, 'y': 1024.0}]}, {'name': 'OBJ2', 'classes': ['Building'], 'coordinates': [{'x': 0.0, 'y': 44.8}, {'x': 105.60000000000001, 'y': 620.8}]}, {'name': 'OBJ3', 'classes': ['Building'], 'coordinates': [{'x': 83.200000512, 'y': 134.4}, {'x': 744.0, 'y': 558.4}]}, {'name': 'OBJ4', 'classes': ['Flower'], 'coordinates': [{'x': 116.80000512000001, 'y': 726.4}, {'x': 140.80000512, 'y': 750.4}]}, {'name': 'OBJ5', 'classes': ['Flower'], 'coordinates': [{'x': 163.2, 'y': 379.2}, {'x': 768.0, 'y': 696.0}]}, {'name': 'OBJ6', 'classes': ['Flower'], 'coordinates': [{'x': 454.39997952, 'y': 803.2}, {'x': 528.0, 'y': 867.2}]}, {'name': 'OBJ7', 'classes': ['Tree'], 'coordinates': [{'x': 35.200000512, 'y': 804.8}, {'x': 416.00002559999996, 'y': 1022.4}]}, {'name': 'OBJ8', 'classes': ['Tree'], 'coordinates': [{'x': 384.0, 'y': 315.2}, {'x': 606.3999744, 'y': 532.8}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 524118},
#  {'id': 2177,
#   'classes': "['Dog']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Dog'], 'coordinates': [{'x': 0.0, 'y': 92.17477725}, {'x': 842.76105216, 'y': 683.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 520971},
#  {'id': 10767,
#   'classes': "['Van']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Van'], 'coordinates': [{'x': 42.24, 'y': 15.999744}, {'x': 904.96, 'y': 746.88}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 492497},
#  {'id': 2407,
#   'classes': "['Person', 'Furniture', 'Table', 'Human body']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Furniture'], 'coordinates': [{'x': 0.0, 'y': 159.58758354}, {'x': 1024.0, 'y': 679.0}]}, {'name': 'OBJ1', 'classes': ['Person'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 290.63528448, 'y': 597.7006819000001}]}, {'name': 'OBJ2', 'classes': ['Person'], 'coordinates': [{'x': 114.44706304, 'y': 12.044345760999999}, {'x': 396.0470528, 'y': 325.1973403}]}, {'name': 'OBJ3', 'classes': ['Human body'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 248.4705792, 'y': 596.1951352}]}, {'name': 'OBJ4', 'classes': ['Human body'], 'coordinates': [{'x': 48.188235776, 'y': 28.605322116}, {'x': 236.4235264, 'y': 340.25277335000004}]}, {'name': 'OBJ5', 'classes': ['Human body'], 'coordinates': [{'x': 155.10588416, 'y': 7.527715846}, {'x': 284.61175808, 'y': 218.30376224999998}]}, {'name': 'OBJ6', 'classes': ['Human body'], 'coordinates': [{'x': 256.0, 'y': 0.0}, {'x': 396.0470528, 'y': 326.70287342}]}, {'name': 'OBJ7', 'classes': ['Human body'], 'coordinates': [{'x': 263.5294208, 'y': 13.549889066}, {'x': 397.5529472, 'y': 204.75388948}]}, {'name': 'OBJ8', 'classes': ['Table'], 'coordinates': [{'x': 0.0, 'y': 209.270516}, {'x': 128.0, 'y': 335.73614683}]}, {'name': 'OBJ9', 'classes': ['Table'], 'coordinates': [{'x': 0.0, 'y': 334.23060692}, {'x': 609.8823168, 'y': 679.0}]}, {'name': 'OBJ10', 'classes': ['Table'], 'coordinates': [{'x': 109.92941056, 'y': 212.28159582}, {'x': 671.62353664, 'y': 334.23060692}]}, {'name': 'OBJ11', 'classes': ['Table'], 'coordinates': [{'x': 140.0470528, 'y': 123.45455100999999}, {'x': 396.0470528, 'y': 210.7760627}]}, {'name': 'OBJ12', 'classes': ['Table'], 'coordinates': [{'x': 430.68234752, 'y': 130.98225735}, {'x': 777.035264, 'y': 180.6651966}]}, {'name': 'OBJ13', 'classes': ['Table'], 'coordinates': [{'x': 447.24707328, 'y': 371.86918614999996}, {'x': 1024.0, 'y': 602.21728805}]}, {'name': 'OBJ14', 'classes': ['Table'], 'coordinates': [{'x': 448.75292672, 'y': 371.86918614999996}, {'x': 1022.49413632, 'y': 679.0}]}, {'name': 'OBJ15', 'classes': ['Table'], 'coordinates': [{'x': 643.0117888, 'y': 219.80930216000002}, {'x': 1024.0, 'y': 374.88027275999997}]}, {'name': 'OBJ16', 'classes': ['Table'], 'coordinates': [{'x': 643.0117888, 'y': 221.31484886}, {'x': 1022.49413632, 'y': 296.5920209}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 531350},
#  {'id': 10768,
#   'classes': "['Girl']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Girl'], 'coordinates': [{'x': 205.669058, 'y': 130.56}, {'x': 638.790776, 'y': 1024.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 458366},
#  {'id': 10769,
#   'classes': "['Cat']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Cat'], 'coordinates': [{'x': 74.88, 'y': 230.444415}, {'x': 921.6, 'y': 487.77447600000005}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 435579},
#  {'id': 10045,
#   'classes': "['Headphones']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Headphones'], 'coordinates': [{'x': 495.36, 'y': 100.59223999999999}, {'x': 611.84, 'y': 252.440898}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 349436},
#  {'id': 10046,
#   'classes': "['Wine glass']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Wine glass'], 'coordinates': [{'x': 961.333248, 'y': 452.66688}, {'x': 1023.333376, 'y': 706.6667520000001}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 452853},
#  {'id': 10066,
#   'classes': "['Mammal']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Mammal'], 'coordinates': [{'x': 135.99999744000002, 'y': 128.0}, {'x': 668.80000512, 'y': 942.4}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 519695},
#  {'id': 10067,
#   'classes': "['Food']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Food'], 'coordinates': [{'x': 0.0, 'y': 33.599999999999994}, {'x': 1024.0, 'y': 768.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 531158},
#  {'id': 10068,
#   'classes': "['Truck']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Truck'], 'coordinates': [{'x': 7.5516223488, 'y': 120.88495545}, {'x': 999.8347776, 'y': 636.1570597}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 513705},
#  {'id': 11210,
#   'classes': "['Cucumber']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Cucumber'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1024.0, 'y': 695.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 529963},
#  {'id': 10136,
#   'classes': "['Skull']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Skull'], 'coordinates': [{'x': 273.28, 'y': 34.56}, {'x': 762.88, 'y': 629.1202559999999}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 357079},
#  {'id': 10137,
#   'classes': "['Car']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Car'], 'coordinates': [{'x': 91.52, 'y': 106.880256}, {'x': 972.16, 'y': 577.92}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 372657},
#  {'id': 10151,
#   'classes': "['Nail']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Nail'], 'coordinates': [{'x': 835.84, 'y': 378.879744}, {'x': 862.72, 'y': 504.96}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 442920},
#  {'id': 10152,
#   'classes': "['Rhinoceros']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Rhinoceros'], 'coordinates': [{'x': 34.548074, 'y': 172.8}, {'x': 611.625102, 'y': 883.2}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 441488},
#  {'id': 12288,
#   'classes': "['Coin']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Coin'], 'coordinates': [{'x': 269.44, 'y': 159.999744}, {'x': 745.6, 'y': 613.760256}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 349479},
#  {'id': 11696,
#   'classes': "['Camera']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Camera'], 'coordinates': [{'x': 120.18779136, 'y': 22.429166923}, {'x': 899.0047232, 'y': 769.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 535037},
#  {'id': 11697,
#   'classes': "['Office supplies']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Office supplies'], 'coordinates': [{'x': 135.91554048, 'y': 68.00000340000001}, {'x': 917.4298624, 'y': 676.9090566}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 517026},
#  {'id': 11795,
#   'classes': "['Vegetable']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Vegetable'], 'coordinates': [{'x': 25.6, 'y': 78.4035512}, {'x': 1024.0, 'y': 622.705104}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 523994},
#  {'id': 11826,
#   'classes': "['Mammal', 'Human arm', 'Person', 'Furniture', 'Clothing', 'Man', 'Building', 'Human hair', 'Human body']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human hair'], 'coordinates': [{'x': 126.92920493, 'y': 714.3834624}, {'x': 176.79424948, 'y': 767.2448}]}, {'name': 'OBJ1', 'classes': ['Human hair'], 'coordinates': [{'x': 134.48450995000002, 'y': 622.2536704}, {'x': 154.12832076, 'y': 632.8259584}]}, {'name': 'OBJ2', 'classes': ['Human hair'], 'coordinates': [{'x': 187.37167924, 'y': 756.67254272}, {'x': 210.03760796, 'y': 780.8377856}]}, {'name': 'OBJ3', 'classes': ['Human hair'], 'coordinates': [{'x': 207.01548322, 'y': 619.23303424}, {'x': 226.6592872, 'y': 634.3363072}]}, {'name': 'OBJ4', 'classes': ['Human hair'], 'coordinates': [{'x': 232.70353667999998, 'y': 730.9970432}, {'x': 268.96901990000003, 'y': 768.7552}]}, {'name': 'OBJ5', 'classes': ['Human hair'], 'coordinates': [{'x': 249.32521592, 'y': 749.1209728}, {'x': 327.9004455, 'y': 835.2094208}]}, {'name': 'OBJ6', 'classes': ['Human hair'], 'coordinates': [{'x': 281.05751885999996, 'y': 848.80236544}, {'x': 362.65485269, 'y': 927.3392128}]}, {'name': 'OBJ7', 'classes': ['Human hair'], 'coordinates': [{'x': 293.14601782, 'y': 617.72271616}, {'x': 309.76769706, 'y': 628.2949632}]}, {'name': 'OBJ8', 'classes': ['Human hair'], 'coordinates': [{'x': 306.74557232, 'y': 732.50738176}, {'x': 347.54424948, 'y': 756.67254272}]}, {'name': 'OBJ9', 'classes': ['Human hair'], 'coordinates': [{'x': 355.09955449999995, 'y': 682.6667008}, {'x': 397.4092872, 'y': 735.5280384}]}, {'name': 'OBJ10', 'classes': ['Human hair'], 'coordinates': [{'x': 404.96460588, 'y': 815.5751936}, {'x': 679.97789575, 'y': 1024.0}]}, {'name': 'OBJ11', 'classes': ['Human hair'], 'coordinates': [{'x': 430.65263885, 'y': 752.1416192}, {'x': 469.94026729999996, 'y': 783.8583808}]}, {'name': 'OBJ12', 'classes': ['Human hair'], 'coordinates': [{'x': 439.71901990000003, 'y': 617.72271616}, {'x': 456.3407128, 'y': 628.2949632}]}, {'name': 'OBJ13', 'classes': ['Human hair'], 'coordinates': [{'x': 488.07300208, 'y': 643.3982464}, {'x': 506.20575052, 'y': 658.50146816}]}, {'name': 'OBJ14', 'classes': ['Human hair'], 'coordinates': [{'x': 492.6061687, 'y': 711.3628672}, {'x': 531.8938313, 'y': 756.67254272}]}, {'name': 'OBJ15', 'classes': ['Human hair'], 'coordinates': [{'x': 528.8716929, 'y': 740.0590336}, {'x': 554.5597327, 'y': 770.2654976}]}, {'name': 'OBJ16', 'classes': ['Human hair'], 'coordinates': [{'x': 539.449109, 'y': 638.8672512}, {'x': 557.5818711000001, 'y': 652.46020608}]}, {'name': 'OBJ17', 'classes': ['Human hair'], 'coordinates': [{'x': 550.0265251, 'y': 740.0590336}, {'x': 646.7344962899999, 'y': 841.2507136}]}, {'name': 'OBJ18', 'classes': ['Human hair'], 'coordinates': [{'x': 605.93586011, 'y': 715.89380096}, {'x': 633.1349622800001, 'y': 746.10028544}]}, {'name': 'OBJ19', 'classes': ['Human hair'], 'coordinates': [{'x': 619.53539412, 'y': 638.8672512}, {'x': 640.6902673, 'y': 658.50146816}]}, {'name': 'OBJ20', 'classes': ['Human hair'], 'coordinates': [{'x': 658.82300208, 'y': 656.9911296}, {'x': 681.4889308, 'y': 679.6460032}]}, {'name': 'OBJ21', 'classes': ['Human hair'], 'coordinates': [{'x': 661.84514731, 'y': 720.4248064}, {'x': 683.0, 'y': 752.1416192}]}, {'name': 'OBJ22', 'classes': ['Furniture'], 'coordinates': [{'x': 0.0, 'y': 666.05312}, {'x': 655.800891, 'y': 1024.0}]}, {'name': 'OBJ23', 'classes': ['Building'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 683.0, 'y': 1024.0}]}, {'name': 'OBJ24', 'classes': ['Person'], 'coordinates': [{'x': 67.99778616, 'y': 616.2123776}, {'x': 683.0, 'y': 1024.0}]}, {'name': 'OBJ25', 'classes': ['Clothing'], 'coordinates': [{'x': 63.464602465, 'y': 774.79645184}, {'x': 214.5708019, 'y': 975.66961664}]}, {'name': 'OBJ26', 'classes': ['Clothing'], 'coordinates': [{'x': 117.86283071, 'y': 647.92920064}, {'x': 178.30530502, 'y': 743.0796288}]}, {'name': 'OBJ27', 'classes': ['Clothing'], 'coordinates': [{'x': 170.75, 'y': 921.29792}, {'x': 403.45353668, 'y': 1024.0}]}, {'name': 'OBJ28', 'classes': ['Clothing'], 'coordinates': [{'x': 178.30530502, 'y': ...
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 540078},
#  {'id': 11827,
#   'classes': "['Tree']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Tree'], 'coordinates': [{'x': 0.0, 'y': 258.39159014}, {'x': 1022.4897024, 'y': 683.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 513035},
#  {'id': 3315,
#   'classes': "['Insect', 'Spider']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Spider'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 804.3584762200001, 'y': 1024.0}]}, {'name': 'OBJ1', 'classes': ['Insect'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 806.0, 'y': 1024.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 539588},
#  {'id': 3440,
#   'classes': "['Tree', 'Fruit']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Fruit'], 'coordinates': [{'x': 0.0, 'y': 128.26877602}, {'x': 1024.0, 'y': 854.0}]}, {'name': 'OBJ1', 'classes': ['Tree'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1022.3102464, 'y': 850.62451376}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 540217},
#  {'id': 11828,
#   'classes': "['Maple']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Maple'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1024.0, 'y': 768.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 521418},
#  {'id': 11829,
#   'classes': "['Car']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Car'], 'coordinates': [{'x': 98.171088896, 'y': 0.0}, {'x': 992.28320768, 'y': 681.4889308}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 540356},
#  {'id': 12055,
#   'classes': "['Vehicle registration plate']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Vehicle registration plate'], 'coordinates': [{'x': 472.32, 'y': 401.08628600000003}, {'x': 559.36, 'y': 452.343387}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 484016},
#  {'id': 12079,
#   'classes': "['Airplane']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Airplane'], 'coordinates': [{'x': 10.999808, 'y': 119.999685}, {'x': 1013.000192, 'y': 463.00023600000003}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 343866},
#  {'id': 12080,
#   'classes': "['Mirror']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Mirror'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 970.88, 'y': 578.3596259999999}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 379001},
#  {'id': 12081,
#   'classes': "['Bird']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Bird'], 'coordinates': [{'x': 60.8, 'y': 103.154856}, {'x': 599.04, 'y': 504.881796}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 331257},
#  {'id': 12082,
#   'classes': "['Airplane']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Airplane'], 'coordinates': [{'x': 0.0, 'y': 251.358695}, {'x': 1023.36, 'y': 684.36021}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 501528},
#  {'id': 12083,
#   'classes': "['Tent']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Tent'], 'coordinates': [{'x': 0.0, 'y': 515.840256}, {'x': 371.2, 'y': 767.360256}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 358519},
#  {'id': 12326,
#   'classes': "['Human hair']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human hair'], 'coordinates': [{'x': 197.06295, 'y': 188.8}, {'x': 703.7957779999999, 'y': 761.6}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 448548},
#  {'id': 12568,
#   'classes': "['Airplane']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Airplane'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1022.400512, 'y': 680.399346}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 324942},
#  {'id': 12588,
#   'classes': "['Building']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Building'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 682.359346, 'y': 843.52}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 437962},
#  {'id': 13792,
#   'classes': "['Food']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Food'], 'coordinates': [{'x': 28.444672, 'y': 38.483968}, {'x': 1007.26784, 'y': 936.993792}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 341033},
#  {'id': 12654,
#   'classes': "['Airplane']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Airplane'], 'coordinates': [{'x': 366.72, 'y': 243.20025599999997}, {'x': 680.32, 'y': 509.43974399999996}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 436386},
#  {'id': 12655,
#   'classes': "['Shirt']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Shirt'], 'coordinates': [{'x': 278.4, 'y': 265.6}, {'x': 767.360256, 'y': 1023.36}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 350055},
#  {'id': 4165,
#   'classes': "['Pasta']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Pasta'], 'coordinates': [{'x': 158.58407424, 'y': 33.243363944}, {'x': 987.75220224, 'y': 678.46681972}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 518013},
#  {'id': 4315,
#   'classes': "['Car', 'Vehicle', 'Land vehicle']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Car'], 'coordinates': [{'x': 0.0, 'y': 178.1773848}, {'x': 52.78350336, 'y': 206.8669614}]}, {'name': 'OBJ1', 'classes': ['Car'], 'coordinates': [{'x': 0.0, 'y': 203.84701242}, {'x': 265.42563328, 'y': 452.9933685}]}, {'name': 'OBJ2', 'classes': ['Car'], 'coordinates': [{'x': 227.72313088, 'y': 188.74723347}, {'x': 757.06628096, 'y': 531.5121918}]}, {'name': 'OBJ3', 'classes': ['Car'], 'coordinates': [{'x': 491.64065792, 'y': 173.64744090000002}, {'x': 621.3372928, 'y': 196.29711273}]}, {'name': 'OBJ4', 'classes': ['Car'], 'coordinates': [{'x': 867.1576064, 'y': 178.1773848}, {'x': 975.74078464, 'y': 212.90687298}]}, {'name': 'OBJ5', 'classes': ['Car'], 'coordinates': [{'x': 892.7952896, 'y': 184.21730999999997}, {'x': 1024.0, 'y': 539.0620983}]}, {'name': 'OBJ6', 'classes': ['Land vehicle'], 'coordinates': [{'x': 104.058906624, 'y': 123.81818738999999}, {'x': 399.64654592, 'y': 211.39690530000001}]}, {'name': 'OBJ7', 'classes': ['Vehicle'], 'coordinates': [{'x': 490.13254144, 'y': 170.62749192}, {'x': 621.3372928, 'y': 212.90687298}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 533680},
#  {'id': 12656,
#   'classes': "['Wheel', 'Tire']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Tire', 'Wheel'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 680.3598599999999, 'y': 1023.36}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 363084},
#  {'id': 13628,
#   'classes': "['Clothing']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Clothing'], 'coordinates': [{'x': 672.0, 'y': 276.98983999999996}, {'x': 977.28, 'y': 660.1691599999999}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 316174},
#  {'id': 13855,
#   'classes': "['Motorcycle']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Motorcycle'], 'coordinates': [{'x': 16.64, 'y': 48.072618000000006}, {'x': 1015.04, 'y': 574.94907}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 474192},
#  {'id': 14234,
#   'classes': "['Rocket']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Rocket'], 'coordinates': [{'x': 43.52, 'y': 191.44992000000002}, {'x': 1024.0, 'y': 676.158}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 492344},
#  {'id': 14259,
#   'classes': "['Stairs']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Stairs'], 'coordinates': [{'x': 574.08, 'y': 690.85064}, {'x': 902.4, 'y': 759.36008}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 492596},
#  {'id': 14368,
#   'classes': "['Clothing']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Clothing'], 'coordinates': [{'x': 787.2, 'y': 852.799488}, {'x': 972.8, 'y': 1022.400512}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 403497},
#  {'id': 14369,
#   'classes': "['Mirror']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Mirror'], 'coordinates': [{'x': 151.04, 'y': 274.108802}, {'x': 607.36, 'y': 594.329076}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 504245},
#  {'id': 14459,
#   'classes': "['Vegetable']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Vegetable'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1023.36, 'y': 767.360256}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 329881},
#  {'id': 4653,
#   'classes': "['Hamburger', 'Fast food', 'Baked goods']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Baked goods'], 'coordinates': [{'x': 79.999997952, 'y': 280.0}, {'x': 627.19999488, 'y': 804.8}]}, {'name': 'OBJ1', 'classes': ['Fast food'], 'coordinates': [{'x': 91.19999999999999, 'y': 275.2}, {'x': 627.19999488, 'y': 809.6}]}, {'name': 'OBJ2', 'classes': ['Hamburger'], 'coordinates': [{'x': 86.4, 'y': 280.0}, {'x': 627.19999488, 'y': 800.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 513320},
#  {'id': 16263,
#   'classes': "['Chair']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Chair'], 'coordinates': [{'x': 199.68, 'y': 540.8}, {'x': 398.079744, 'y': 866.56}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 441548},
#  {'id': 14379,
#   'classes': "['Flower']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Flower'], 'coordinates': [{'x': 303.288545, 'y': 447.200256}, {'x': 465.73629500000004, 'y': 586.399744}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 426547},
#  {'id': 14455,
#   'classes': "['Lamp']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Lamp'], 'coordinates': [{'x': 520.96, 'y': 0.0}, {'x': 716.16, 'y': 353.279808}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 444962},
#  {'id': 4782,
#   'classes': "['Human face', 'Bicycle', 'Boy', 'Clothing', 'Land vehicle', 'Wheel', 'Man', 'Human head', 'Helmet', 'Sports equipment']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human face'], 'coordinates': [{'x': 582.5689088, 'y': 249.27573999999998}, {'x': 633.61876992, 'y': 312.3455148}]}, {'name': 'OBJ1', 'classes': ['Human face'], 'coordinates': [{'x': 600.58648576, 'y': 249.27573999999998}, {'x': 639.62463232, 'y': 312.3455148}]}, {'name': 'OBJ2', 'classes': ['Bicycle'], 'coordinates': [{'x': 204.199424, 'y': 615.6810424}, {'x': 450.4398848, 'y': 861.9534684}]}, {'name': 'OBJ3', 'classes': ['Bicycle'], 'coordinates': [{'x': 435.4252288, 'y': 729.8073360000001}, {'x': 504.49267712, 'y': 795.8804248}]}, {'name': 'OBJ4', 'classes': ['Bicycle'], 'coordinates': [{'x': 561.5483904, 'y': 612.6777736}, {'x': 798.7800064, 'y': 852.9435264}]}, {'name': 'OBJ5', 'classes': ['Clothing'], 'coordinates': [{'x': 504.49267712, 'y': 306.33887776}, {'x': 648.6334464, 'y': 615.6810424}]}, {'name': 'OBJ6', 'classes': ['Land vehicle'], 'coordinates': [{'x': 201.19648256, 'y': 498.55147999999997}, {'x': 801.78301952, 'y': 855.9468494399999}]}, {'name': 'OBJ7', 'classes': ['Human head'], 'coordinates': [{'x': 534.5219584, 'y': 213.2358816}, {'x': 633.61876992, 'y': 312.3455148}]}, {'name': 'OBJ8', 'classes': ['Wheel'], 'coordinates': [{'x': 201.19648256, 'y': 618.6843654400001}, {'x': 444.4340224, 'y': 855.9468494399999}]}, {'name': 'OBJ9', 'classes': ['Wheel'], 'coordinates': [{'x': 555.542528, 'y': 618.6843654400001}, {'x': 798.7800064, 'y': 855.9468494399999}]}, {'name': 'OBJ10', 'classes': ['Sports equipment'], 'coordinates': [{'x': 201.19648256, 'y': 501.55480303999997}, {'x': 798.7800064, 'y': 855.9468494399999}]}, {'name': 'OBJ11', 'classes': ['Sports equipment'], 'coordinates': [{'x': 540.5278208, 'y': 213.2358816}, {'x': 627.61291776, 'y': 306.33887776}]}, {'name': 'OBJ12', 'classes': ['Boy'], 'coordinates': [{'x': 504.49267712, 'y': 207.22924455999998}, {'x': 672.656896, 'y': 846.9368984}]}, {'name': 'OBJ13', 'classes': ['Helmet'], 'coordinates': [{'x': 528.516096, 'y': 210.23256759999998}, {'x': 633.61876992, 'y': 315.34882880000004}]}, {'name': 'OBJ14', 'classes': ['Man'], 'coordinates': [{'x': 504.49267712, 'y': 213.2358816}, {'x': 669.6539136, 'y': 840.9302703999999}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 529781},
#  {'id': 14456,
#   'classes': "['Rabbit']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Rabbit'], 'coordinates': [{'x': 544.925696, 'y': 539.703025}, {'x': 790.224896, 'y': 773.354675}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 496903},
#  {'id': 14457,
#   'classes': "['Helicopter']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Helicopter'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1023.36, 'y': 677.359968}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 454928},
#  {'id': 4949,
#   'classes': "['Human mouth', 'Human face', 'Human head', 'Suit', 'Human eye', 'Human hair', 'Man']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human face'], 'coordinates': [{'x': 407.78760192, 'y': 31.732301573999997}, {'x': 693.23894784, 'y': 336.96681972}]}, {'name': 'OBJ1', 'classes': ['Human face'], 'coordinates': [{'x': 454.6076672, 'y': 61.953540095}, {'x': 643.3982464, 'y': 339.98894445999997}]}, {'name': 'OBJ2', 'classes': ['Suit'], 'coordinates': [{'x': 178.2182912, 'y': 291.63496227999997}, {'x': 916.76696576, 'y': 683.0}]}, {'name': 'OBJ3', 'classes': ['Human hair'], 'coordinates': [{'x': 407.78760192, 'y': 28.710176151000002}, {'x': 693.23894784, 'y': 293.14601782}]}, {'name': 'OBJ4', 'classes': ['Human head'], 'coordinates': [{'x': 407.78760192, 'y': 30.221238520999997}, {'x': 691.72864, 'y': 338.47787525999996}]}, {'name': 'OBJ5', 'classes': ['Human eye'], 'coordinates': [{'x': 492.36578304, 'y': 169.23893762999998}, {'x': 536.1652224, 'y': 187.37167924}]}, {'name': 'OBJ6', 'classes': ['Human eye'], 'coordinates': [{'x': 573.9232768, 'y': 167.72787526000002}, {'x': 620.7433728, 'y': 188.88274844}]}, {'name': 'OBJ7', 'classes': ['Human mouth'], 'coordinates': [{'x': 502.93805056, 'y': 249.32521592}, {'x': 592.0472064, 'y': 281.05751885999996}]}, {'name': 'OBJ8', 'classes': ['Man'], 'coordinates': [{'x': 176.70796288, 'y': 309.76769706}, {'x': 915.2566272, 'y': 683.0}]}, {'name': 'OBJ9', 'classes': ['Man'], 'coordinates': [{'x': 178.2182912, 'y': 30.221238520999997}, {'x': 915.2566272, 'y': 683.0}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 528312},
#  {'id': 16264,
#   'classes': "['Curtain']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Curtain'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 682.359346, 'y': 1023.36}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 448138},
#  {'id': 16349,
#   'classes': "['Plate']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Plate'], 'coordinates': [{'x': 30.72, 'y': 0.0}, {'x': 1023.36, 'y': 767.360256}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 474624},
#  {'id': 14472,
#   'classes': "['Microphone']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Microphone'], 'coordinates': [{'x': 600.32, 'y': 411.337433}, {'x': 827.52, 'y': 549.731674}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 480852},
#  {'id': 14495,
#   'classes': "['Human hair']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human hair'], 'coordinates': [{'x': 32.768255999999994, 'y': 0.0}, {'x': 693.589248, 'y': 817.152}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 442673},
#  {'id': 14496,
#   'classes': "['Door']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Door'], 'coordinates': [{'x': 29.44, 'y': 310.10522199999997}, {'x': 362.24, 'y': 682.359346}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
# ...
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 365269},
#  {'id': 10841,
#   'classes': "['Car', 'Wheel', 'Palm tree', 'House', 'Tire']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['House'], 'coordinates': [{'x': 28.8, 'y': 187.728697}, {'x': 571.52, 'y': 468.361103}]}, {'name': 'OBJ1', 'classes': ['Palm tree'], 'coordinates': [{'x': 768.0, 'y': 62.789556}, {'x': 1004.16, 'y': 482.456857}]}, {'name': 'OBJ2', 'classes': ['Car'], 'coordinates': [{'x': 779.52, 'y': 425.43318700000003}, {'x': 937.6, 'y': 567.030698}]}, {'name': 'OBJ3', 'classes': ['Wheel'], 'coordinates': [{'x': 755.2, 'y': 509.367057}, {'x': 787.2, 'y': 579.845144}]}, {'name': 'OBJ4', 'classes': ['Wheel'], 'coordinates': [{'x': 914.56, 'y': 511.929673}, {'x': 948.48, 'y': 568.312689}]}, {'name': 'OBJ5', 'classes': ['Palm tree'], 'coordinates': [{'x': 16.64, 'y': 76.24465599999999}, {'x': 117.12, 'y': 407.493509}]}, {'name': 'OBJ6', 'classes': ['Palm tree'], 'coordinates': [{'x': 376.96, 'y': 155.05261099999998}, {'x': 475.52, 'y': 269.099268}]}, {'name': 'OBJ7', 'classes': ['Tire'], 'coordinates': [{'x': 757.76, 'y': 514.492289}, {'x': 788.48, 'y': 570.875305}]}, {'name': 'OBJ8', 'classes': ['Tire'], 'coordinates': [{'x': 913.28, 'y': 490.145388}, {'x': 942.08, 'y': 542.683797}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 355230},
#  {'id': 10842,
#   'classes': "['Tree', 'Human face', 'Clothing', 'Animal', 'Woman']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Woman'], 'coordinates': [{'x': 537.6, 'y': 534.4}, {'x': 892.8, 'y': 1022.400512}]}, {'name': 'OBJ1', 'classes': ['Tree'], 'coordinates': [{'x': 536.000512, 'y': 0.0}, {'x': 894.400512, 'y': 545.599488}]}, {'name': 'OBJ2', 'classes': ['Clothing'], 'coordinates': [{'x': 702.400512, 'y': 929.599488}, {'x': 888.000512, 'y': 1022.400512}]}, {'name': 'OBJ3', 'classes': ['Human face'], 'coordinates': [{'x': 652.8, 'y': 609.599488}, {'x': 844.8, 'y': 948.799488}]}, {'name': 'OBJ4', 'classes': ['Animal'], 'coordinates': [{'x': 116.800512, 'y': 0.0}, {'x': 659.2, 'y': 659.2}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 429731},
#  {'id': 10878,
#   'classes': "['Plate', 'Saucer', 'Platter', 'Spoon', 'Fork']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Saucer'], 'coordinates': [{'x': 142.08, 'y': 238.985798}, {'x': 829.44, 'y': 504.24114199999997}]}, {'name': 'OBJ1', 'classes': ['Plate'], 'coordinates': [{'x': 145.92, 'y': 243.471059}, {'x': 830.08, 'y': 502.31918}]}, {'name': 'OBJ2', 'classes': ['Platter'], 'coordinates': [{'x': 142.72, 'y': 242.83040499999998}, {'x': 831.36, 'y': 508.726403}]}, {'name': 'OBJ3', 'classes': ['Spoon'], 'coordinates': [{'x': 299.52, 'y': 277.428453}, {'x': 1023.36, 'y': 392.116447}]}, {'name': 'OBJ4', 'classes': ['Fork'], 'coordinates': [{'x': 0.0, 'y': 160.178526}, {'x': 113.92, 'y': 337.014739}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 346629},
#  {'id': 10843,
#   'classes': "['Flower']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Flower'], 'coordinates': [{'x': 5.12, 'y': 254.18732}, {'x': 28.16, 'y': 277.2366}]}, {'name': 'OBJ1', 'classes': ['Flower'], 'coordinates': [{'x': 305.28, 'y': 59.54524}, {'x': 321.28, 'y': 93.47924}]}, {'name': 'OBJ2', 'classes': ['Flower'], 'coordinates': [{'x': 316.8, 'y': 0.0}, {'x': 341.76, 'y': 40.97692}]}, {'name': 'OBJ3', 'classes': ['Flower'], 'coordinates': [{'x': 325.12, 'y': 49.300439999999995}, {'x': 347.52, 'y': 67.22807999999999}]}, {'name': 'OBJ4', 'classes': ['Flower'], 'coordinates': [{'x': 347.52, 'y': 60.82583999999999}, {'x': 356.48, 'y': 79.3934}]}, {'name': 'OBJ5', 'classes': ['Flower'], 'coordinates': [{'x': 376.32, 'y': 62.10644}, {'x': 392.96, 'y': 79.3934}]}, {'name': 'OBJ6', 'classes': ['Flower'], 'coordinates': [{'x': 494.08, 'y': 416.81516}, {'x': 512.64, 'y': 434.74280000000005}]}, {'name': 'OBJ7', 'classes': ['Flower'], 'coordinates': [{'x': 495.36, 'y': 277.2366}, {'x': 522.88, 'y': 295.80492}]}, {'name': 'OBJ8', 'classes': ['Flower'], 'coordinates': [{'x': 512.64, 'y': 411.69352000000003}, {'x': 531.2, 'y': 421.93756}]}, {'name': 'OBJ9', 'classes': ['Flower'], 'coordinates': [{'x': 520.32, 'y': 284.27952}, {'x': 535.04, 'y': 306.68888}]}, {'name': 'OBJ10', 'classes': ['Flower'], 'coordinates': [{'x': 522.88, 'y': 487.24512}, {'x': 563.84, 'y': 526.9422}]}, {'name': 'OBJ11', 'classes': ['Flower'], 'coordinates': [{'x': 529.92, 'y': 430.90176}, {'x': 546.56, 'y': 444.34692}]}, {'name': 'OBJ12', 'classes': ['Flower'], 'coordinates': [{'x': 537.6, 'y': 268.27316}, {'x': 556.16, 'y': 290.68252}]}, {'name': 'OBJ13', 'classes': ['Flower'], 'coordinates': [{'x': 721.28, 'y': 411.69352000000003}, {'x': 739.84, 'y': 432.18160000000006}]}, {'name': 'OBJ14', 'classes': ['Flower'], 'coordinates': [{'x': 757.76, 'y': 28.17168}, {'x': 780.16, 'y': 49.300439999999995}]}, {'name': 'OBJ15', 'classes': ['Flower'], 'coordinates': [{'x': 769.92, 'y': 13.44592}, {'x': 786.56, 'y': 29.452280000000002}]}, {'name': 'OBJ16', 'classes': ['Flower'], 'coordinates': [{'x': 793.6, 'y': 9.60412}, {'x': 807.68, 'y': 28.17168}]}, {'name': 'OBJ17', 'classes': ['Flower'], 'coordinates': [{'x': 797.44, 'y': 153.02448}, {'x': 819.84, 'y': 164.54912000000002}]}, {'name': 'OBJ18', 'classes': ['Flower'], 'coordinates': [{'x': 927.36, 'y': 618.5001599999999}, {'x': 945.28, 'y': 638.3490800000001}]}, {'name': 'OBJ19', 'classes': ['Flower'], 'coordinates': [{'x': 928.64, 'y': 595.45088}, {'x': 946.56, 'y': 617.21956}]}, {'name': 'OBJ20', 'classes': ['Flower'], 'coordinates': [{'x': 945.28, 'y': 595.45088}, {'x': 970.24, 'y': 619.78076}]}, {'name': 'OBJ21', 'classes': ['Flower'], 'coordinates': [{'x': 962.56, 'y': 644.7513200000001}, {'x': 986.24, 'y': 674.2035999999999}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 346485},
#  {'id': 10844,
#   'classes': "['Tent']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Tent'], 'coordinates': [{'x': 0.0, 'y': 0.0}, {'x': 1023.36, 'y': 701.439744}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 340123},
#  {'id': 10845,
#   'classes': "['Bird']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Bird'], 'coordinates': [{'x': 33.28, 'y': 199.0}, {'x': 51.2, 'y': 217.556352}]}, {'name': 'OBJ1', 'classes': ['Bird'], 'coordinates': [{'x': 33.28, 'y': 220.11588999999998}, {'x': 59.52, 'y': 247.630028}]}, {'name': 'OBJ2', 'classes': ['Bird'], 'coordinates': [{'x': 37.12, 'y': 212.437276}, {'x': 59.52, 'y': 229.07407400000002}]}, {'name': 'OBJ3', 'classes': ['Bird'], 'coordinates': [{'x': 64.64, 'y': 221.39546}, {'x': 93.44, 'y': 255.30864200000002}]}, {'name': 'OBJ4', 'classes': ['Bird'], 'coordinates': [{'x': 264.96, 'y': 196.440462}, {'x': 291.2, 'y': 214.996814}]}, {'name': 'OBJ5', 'classes': ['Bird'], 'coordinates': [{'x': 295.68, 'y': 183.003186}, {'x': 327.04, 'y': 201.55953799999997}]}, {'name': 'OBJ6', 'classes': ['Bird'], 'coordinates': [{'x': 318.72, 'y': 202.839108}, {'x': 355.84, 'y': 229.07407400000002}]}, {'name': 'OBJ7', 'classes': ['Bird'], 'coordinates': [{'x': 379.52, 'y': 108.778176}, {'x': 426.88, 'y': 162.52728}]}, {'name': 'OBJ8', 'classes': ['Bird'], 'coordinates': [{'x': 422.4, 'y': 135.012744}, {'x': 467.2, 'y': 166.366388}]}, {'name': 'OBJ9', 'classes': ['Bird'], 'coordinates': [{'x': 443.52, 'y': 199.0}, {'x': 469.76, 'y': 223.954998}]}, {'name': 'OBJ10', 'classes': ['Bird'], 'coordinates': [{'x': 474.88, 'y': 44.150936}, {'x': 859.52, 'y': 264.90681}]}, {'name': 'OBJ11', 'classes': ['Bird'], 'coordinates': [{'x': 492.16, 'y': 85.10274799999999}, {'x': 528.64, 'y': 119.01593}]}, {'name': 'OBJ12', 'classes': ['Bird'], 'coordinates': [{'x': 564.48, 'y': 107.498208}, {'x': 585.6, 'y': 136.29271200000002}]}, {'name': 'OBJ13', 'classes': ['Bird'], 'coordinates': [{'x': 583.04, 'y': 44.150936}, {'x': 645.76, 'y': 94.060932}]}, {'name': 'OBJ14', 'classes': ['Bird'], 'coordinates': [{'x': 678.4, 'y': 267.466348}, {'x': 728.32, 'y': 301.37953}]}, {'name': 'OBJ15', 'classes': ['Bird'], 'coordinates': [{'x': 728.32, 'y': 250.18956599999999}, {'x': 754.56, 'y': 275.144564}]}, {'name': 'OBJ16', 'classes': ['Bird'], 'coordinates': [{'x': 805.76, 'y': 122.85543600000001}, {'x': 876.8, 'y': 146.53046600000002}]}, {'name': 'OBJ17', 'classes': ['Bird'], 'coordinates': [{'x': 821.76, 'y': 195.16089200000002}, {'x': 880.64, 'y': 229.07407400000002}]}, {'name': 'OBJ18', 'classes': ['Bird'], 'coordinates': [{'x': 838.4, 'y': 108.778176}, {'x': 908.16, 'y': 149.090004}]}, {'name': 'OBJ19', 'classes': ['Bird'], 'coordinates': [{'x': 893.44, 'y': 81.26364}, {'x': 992.0, 'y': 133.733174}]}, {'name': 'OBJ20', 'classes': ['Bird'], 'coordinates': [{'x': 922.24, 'y': 147.81043400000001}, {'x': 965.76, 'y': 196.440462}]}, {'name': 'OBJ21', 'classes': ['Bird'], 'coordinates': [{'x': 931.84, 'y': 151.649542}, {'x': 980.48, 'y': 214.996814}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 494875},
#  {'id': 10846,
#   'classes': "['Human face', 'Footwear', 'Woman', 'Girl', 'Man']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Woman'], 'coordinates': [{'x': 403.057908, 'y': 388.48}, {'x': 591.152144, 'y': 792.96}]}, {'name': 'OBJ1', 'classes': ['Man'], 'coordinates': [{'x': 592.431576, 'y': 83.84}, {'x': 681.360284, 'y': 487.68}]}, {'name': 'OBJ2', 'classes': ['Girl'], 'coordinates': [{'x': 401.13876000000005, 'y': 407.04}, {'x': 582.835154, 'y': 789.76}]}, {'name': 'OBJ3', 'classes': ['Footwear'], 'coordinates': [{'x': 399.859328, 'y': 743.04}, {'x': 450.40166600000003, 'y': 792.32}]}, {'name': 'OBJ4', 'classes': ['Footwear'], 'coordinates': [{'x': 512.4595740000001, 'y': 757.12}, {'x': 592.431576, 'y': 793.6}]}, {'name': 'OBJ5', 'classes': ['Human face'], 'coordinates': [{'x': 81.89115, 'y': 136.96}, {'x': 111.96053, 'y': 177.28}]}, {'name': 'OBJ6', 'classes': ['Human face'], 'coordinates': [{'x': 503.502868, 'y': 432.64}, {'x': 547.647364, 'y': 495.36}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 424939},
#  {'id': 10847,
#   'classes': "['Plant']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Plant'], 'coordinates': [{'x': 0.0, 'y': 208.640256}, {'x': 405.76, 'y': 767.360256}]}, {'name': 'OBJ1', 'classes': ['Plant'], 'coordinates': [{'x': 444.16, 'y': 232.959744}, {'x': 1023.36, 'y': 767.360256}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 444109},
#  {'id': 10848,
#   'classes': "['Sandal', 'Jeans']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Sandal'], 'coordinates': [{'x': 279.658098, 'y': 968.532992}, {'x': 365.05005, 'y': 992.0}]}, {'name': 'OBJ1', 'classes': ['Sandal'], 'coordinates': [{'x': 362.915115, 'y': 934.4}, {'x': 394.93709700000005, 'y': 983.467008}]}, {'name': 'OBJ2', 'classes': ['Jeans'], 'coordinates': [{'x': 271.119039, 'y': 567.467008}, {'x': 424.82414400000005, 'y': 970.667008}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 478210},
#  {'id': 10849,
#   'classes': "['Human mouth', 'Human arm', 'Human face', 'Human nose', 'Woman', 'Human eye', 'Man', 'Human head', 'Bronze sculpture', 'Human hair', 'Human body']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Human body'], 'coordinates': [{'x': 252.00032000000002, 'y': 83.999744}, {'x': 618.999744, 'y': 1022.999552}]}, {'name': 'OBJ1', 'classes': ['Woman'], 'coordinates': [{'x': 321.000064, 'y': 85.000192}, {'x': 613.999936, 'y': 1020.000256}]}, {'name': 'OBJ2', 'classes': ['Human hair'], 'coordinates': [{'x': 356.00012799999996, 'y': 88.000512}, {'x': 583.99968, 'y': 371.999744}]}, {'name': 'OBJ3', 'classes': ['Human head'], 'coordinates': [{'x': 351.00032, 'y': 78.000128}, {'x': 532.999808, 'y': 245.000192}]}, {'name': 'OBJ4', 'classes': ['Human eye'], 'coordinates': [{'x': 132.99968, 'y': 163.999744}, {'x': 145.999744, 'y': 177.999872}]}, {'name': 'OBJ5', 'classes': ['Human eye'], 'coordinates': [{'x': 165.0, 'y': 158.000128}, {'x': 187.99967999999998, 'y': 176.0}]}, {'name': 'OBJ6', 'classes': ['Human eye'], 'coordinates': [{'x': 373.00032, 'y': 145.999872}, {'x': 387.000064, 'y': 163.999744}]}, {'name': 'OBJ7', 'classes': ['Human eye'], 'coordinates': [{'x': 404.999936, 'y': 140.000256}, {'x': 442.99974399999996, 'y': 161.999872}]}, {'name': 'OBJ8', 'classes': ['Bronze sculpture'], 'coordinates': [{'x': 87.00032, 'y': 94.999552}, {'x': 607.000064, 'y': 1018.999808}]}, {'name': 'OBJ9', 'classes': ['Human mouth'], 'coordinates': [{'x': 129.999936, 'y': 204.99968}, {'x': 173.999936, 'y': 225.999872}]}, {'name': 'OBJ10', 'classes': ['Human mouth'], 'coordinates': [{'x': 365.99974399999996, 'y': 186.999808}, {'x': 411.00012799999996, 'y': 216.999936}]}, {'name': 'OBJ11', 'classes': ['Human body'], 'coordinates': [{'x': 72.999872, 'y': 254.999552}, {'x': 362.00032, 'y': 1022.999552}]}, {'name': 'OBJ12', 'classes': ['Human hair'], 'coordinates': [{'x': 204.000192, 'y': 156.000256}, {'x': 237.99987199999998, 'y': 190.000128}]}, {'name': 'OBJ13', 'classes': ['Human head'], 'coordinates': [{'x': 103.00012799999999, 'y': 106.000384}, {'x': 307.00032, 'y': 304.0}]}, {'name': 'OBJ14', 'classes': ['Man'], 'coordinates': [{'x': 83.999872, 'y': 101.000192}, {'x': 345.999808, 'y': 1022.999552}]}, {'name': 'OBJ15', 'classes': ['Human face'], 'coordinates': [{'x': 127.99987200000001, 'y': 144.0}, {'x': 224.999808, 'y': 243.999744}]}, {'name': 'OBJ16', 'classes': ['Human face'], 'coordinates': [{'x': 363.99968, 'y': 115.999744}, {'x': 479.00019199999997, 'y': 243.999744}]}, {'name': 'OBJ17', 'classes': ['Human arm'], 'coordinates': [{'x': 85.999936, 'y': 284.99968}, {'x': 136.000128, 'y': 778.000384}]}, {'name': 'OBJ18', 'classes': ['Human arm'], 'coordinates': [{'x': 105.99987200000001, 'y': 476.99968}, {'x': 153.00032, 'y': 552.999936}]}, {'name': 'OBJ19', 'classes': ['Human arm'], 'coordinates': [{'x': 217.00025599999998, 'y': 273.000448}, {'x': 341.0, 'y': 860.99968}]}, {'name': 'OBJ20', 'classes': ['Human arm'], 'coordinates': [{'x': 275.99968, 'y': 302.000128}, {'x': 600.999872, 'y': 577.000448}]}, {'name': 'OBJ21', 'classes': ['Human nose'], 'coordinates': [{'x': 132.0, 'y': 163.999744}, {'x': 158.999808, 'y': 199.999488}]}, {'name': 'OBJ22', 'classes': ['Human nose'], 'coordinates': [{'x': 369.99987200000004, 'y': 138.000384}, {'x': 402.00019199999997, 'y': 186.999808}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 456239},
#  {'id': 10850,
#   'classes': "['Motorcycle']",
#   'tags': '[]',
#   'task': 'object_detection',
#   'data': "{'objects': [{'name': 'OBJ0', 'classes': ['Motorcycle'], 'coordinates': [{'x': 274.400256, 'y': 136.71985800000002}, {'x': 582.4, 'y': 371.78207000000003}]}]}",
#   'annotation_set_id': 26,
#   'annotation_set_name': 'Object detection',
#   'dataset_id': 6,
#   'image_id': 454183},
#  ...]

# %% [markdown]
# ### TBC -  search for data

# %% [markdown]
# ### ? info on datasets

# %%
sdk.all_info_datasets()
# Out:
# {'count': 6,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 3,
#    'name': 'Open Images V5',
#    'image_thumbnails': [{'id': 6,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/ed5b074d0ae1e020a661727851f9d7c9?Signature=nbkDh8THMSJt1yHVYB4OPk81B80%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/ed5b074d0ae1e020a661727851f9d7c9?Signature=bNTbPyfW8IiSfprF9YllS9ZW1SY%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/ed5b074d0ae1e020a661727851f9d7c9?Signature=NMfGYnAB4BY17xK0pjDEIeeHFzU%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/ed5b074d0ae1e020a661727851f9d7c9?Signature=Z82XHUvNfOUirvhWpALdC%2FrkG9Q%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '13640a5069c55171.jpg',
#      'dataset': {'id': 3,
#       'name': 'Open Images V5',
#       'created_at': '2019-05-26T20:18:13.721502Z',
#       'is_public': True},
#      'dataset_id': 3,
#      'dimensions': [1024, 768],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 37.663113006396586, 'y': 127.72707889125799},
#        {'x': 998.8912579957358, 'y': 671.3859275053305}]],
#      'number_in_dataset': 1,
#      'size_in_bytes': 337430,
#      'created_at': '2019-06-17T11:25:57.568112Z'},
#     {'id': 7,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/ad31e98b1264b2f05a19b5f38ee64a70?Signature=QxVPZWSGoaci%2BHiALP3TtMto0TA%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/ad31e98b1264b2f05a19b5f38ee64a70?Signature=clOtASWg9Z6P7fErIjUZOdF%2FgSg%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/ad31e98b1264b2f05a19b5f38ee64a70?Signature=Czbele0ARRMCWX2Fm5Q8joFr5Ls%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/ad31e98b1264b2f05a19b5f38ee64a70?Signature=NuqW5Nohn4fdbdzL%2FGl9Gnh4fE8%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'cca26d0015d1fbc9.jpg',
#      'dataset': {'id': 3,
#       'name': 'Open Images V5',
#       'created_at': '2019-05-26T20:18:13.721502Z',
#       'is_public': True},
#      'dataset_id': 3,
#      'dimensions': [700, 1024],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 0.015283843, 'y': 0.02238806},
#        {'x': 0.8711790399999999, 'y': 0.97910446}],
#       [{'x': 0.45196506000000003, 'y': 0.07164179},
#        {'x': 0.74017465, 'y': 0.6014925}],
#       [{'x': 0.02183406, 'y': 0.020895522},
#        {'x': 0.87554586, 'y': 0.97313434}],
#       [{'x': 0.015283843, 'y': 0.005970149300000001},
#        {'x': 0.8733624000000001, 'y': 0.9761193999999999}],
#       [{'x': 0.44541484, 'y': 0.017910447}, {'x': 0.5524017, 'y': 0.25820896}],
#       [{'x': 0.65065503, 'y': 0.24626866},
#        {'x': 0.8733624000000001, 'y': 0.31641790000000003}],
#       [{'x': 0.015283843, 'y': 0.0029850746999999997},
#        {'x': 0.8820960500000001, 'y': 0.9805969999999999}],
#       [{'x': 0.019650655, 'y': 0.50298506},
#        {'x': 0.6637555, 'y': 0.9268656999999998}],
#       [{'x': 0.5021834, 'y': 0.59402984},
#        {'x': 0.7838428000000001, 'y': 0.9805969999999999}]],
#      'number_in_dataset': 2,
#      'size_in_bytes': 218536,
#      'created_at': '2019-06-17T11:25:57.568112Z'},
#     {'id': 8,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/db10d4b9ef9083be6f695a6f39ab0d9b?Signature=01kuIvc7Tm4ykM5Uoca%2BEw0NlNg%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/db10d4b9ef9083be6f695a6f39ab0d9b?Signature=7q8ZFJXXZi7n0fd8RnlzQEhARV8%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/db10d4b9ef9083be6f695a6f39ab0d9b?Signature=GvKNHjoHANDkeY56KhXZwnYdseE%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/db10d4b9ef9083be6f695a6f39ab0d9b?Signature=%2BdLPR9HhHmbS1nCada1OnzyhrDg%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '8fa33d4ac35d624f.jpg',
#      'dataset': {'id': 3,
#       'name': 'Open Images V5',
#       'created_at': '2019-05-26T20:18:13.721502Z',
#       'is_public': True},
#      'dataset_id': 3,
#      'dimensions': [1024, 683],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 0, 'y': 0.32964602},
#        {'x': 0.9454277, 'y': 0.8119469}],
#       [{'x': 0.09144543, 'y': 0.61504424}, {'x': 0.23893805, 'y': 0.8141593}],
#       [{'x': 0.36430678, 'y': 0.4358407},
#        {'x': 0.39528023999999995, 'y': 0.45796459999999994}],
#       [{'x': 0.50737464, 'y': 0.39380529999999997},
#        {'x': 0.5398229999999999, 'y': 0.44469026000000006}],
#       [{'x': 0.65929204, 'y': 0.5818584},
#        {'x': 0.8082595999999999, 'y': 0.7876105999999999}]],
#      'number_in_dataset': 3,
#      'size_in_bytes': 104301,
#      'created_at': '2019-06-17T11:25:57.568112Z'},
#     {'id': 9,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/13c94b991e09e35c9925af5bfe12eb97?Signature=hzHv6HNK6p07dvOSL2zsAwwcSO8%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/13c94b991e09e35c9925af5bfe12eb97?Signature=BrEEvhkFSO4X5RKRxrWoK13YA%2FQ%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/13c94b991e09e35c9925af5bfe12eb97?Signature=bSlR%2B4svj%2FBJUas40uKe4GKIxJo%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/13c94b991e09e35c9925af5bfe12eb97?Signature=G4WsdkFNU2K6VD1%2FzIvxJSEJTOs%3D&Expires=1571217304&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'acff9c78f7679620.jpg',
#      'dataset': {'id': 3,
#       'name': 'Open Images V5',
#       'created_at': '2019-05-26T20:18:13.721502Z',
#       'is_public': True},
#      'dataset_id': 3,
#      'dimensions': [1024, 683],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 0.07964602, 'y': 0.5707965},
#        {'x': 0.16371681, 'y': 0.8163717}],
#       [{'x': 0.09439528, 'y': 0.38716814}, {'x': 0.17256637, 'y': 0.84292036}],
#       [{'x': 0, 'y': 0}, {'x': 0.99557525, 'y': 0.6216814}],
#       [{'x': 0.020648967, 'y': 0.06637168}, {'x': 0.17109145, 'y': 0.8473451}],
#       [{'x': 0.14159292, 'y': 0.12831858}, {'x': 0.33923304, 'y': 0.7654867}],
#       [{'x': 0.42625368, 'y': 0.36946902},
#        {'x': 0.6401180000000001, 'y': 0.7477876}],
#       [{'x': 0.5958701999999999, 'y': 0.35840708},
#        {'x': 0.78466076, 'y': 0.79646015}],
#       [{'x': 0.6902655, 'y': 0.23230087999999996},
#        {'x': 0.9572271000000001, 'y': 0.9181415999999999}],
#       [{'x': 0.06637168, 'y': 0.061946902},
#        {'x': 0.16371681, 'y': 0.17699115}],
#       [{'x': 0.16666667, 'y': 0.12831858},
#        {'x': 0.25221238, 'y': 0.23230087999999996}],
#       [{'x': 0.5575220999999999, 'y': 0.3738938},
#        {'x': 0.63274336, 'y': 0.46238938}],
#       [{'x': 0.6858407, 'y': 0.23451327},
#        {'x': 0.8067846999999999, 'y': 0.36725664}],
#       [{'x': 0.15781711, 'y': 0.38495576}, {'x': 0.21828909, 'y': 0.7654867}],
#       [{'x': 0.02359882, 'y': 0.06415929},
#        {'x': 0.17404129999999998, 'y': 0.8517699000000001}],
#       [{'x': 0.14454277, 'y': 0.13495575}, {'x': 0.33628318, 'y': 0.7632743}],
#       [{'x': 0.42625368, 'y': 0.36725664}, {'x': 0.63716817, 'y': 0.7477876}],
#       [{'x': 0.6017699000000001, 'y': 0.35840708},
#        {'x': 0.8362832, 'y': 0.7986725599999999}],
#       [{'x': 0.68731564, 'y': 0.23451327},
#        {'x': 0.9557521999999999, 'y': 0.92477876}],
#       [{'x': 0.02359882, 'y': 0.06637168}, {'x': 0.17551622, 'y': 0.84070796}],
#       [{'x': 0.14159292, 'y': 0.13053097}, {'x': 0.33775812, 'y': 0.7676991}],
#       [{'x': 0.42477876, 'y': 0.37168142},
#        {'x': 0.6342183000000001, 'y': 0.7522124}],
#       [{'x': 0.45870206, 'y': 0.7123894000000001},
#        {'x': 0.61946905, 'y': 0.8362832}],
#       [{'x': 0.5958701999999999, 'y': 0.36283186},
#        {'x': 0.79646015, 'y': 0.79646015}],
#       [{'x': 0.22418879000000003, 'y': 0.38716814},
#        {'x': 0.28761062, 'y': 0.7522124}],
#       [{'x': 0.68879056, 'y': 0.23451327},
#        {'x': 0.9572271000000001, 'y': 0.9181415999999999}],
#       [{'x': 0.025073746, 'y': 0.07300885},
#        {'x': 0.17846608, 'y': 0.8517699000000001}],
#       [{'x': 0.13864307, 'y': 0.13053097}, {'x': 0.33628318, 'y': 0.7632743}],
#       [{'x': 0.42920354, 'y': 0.3805309800000001},
#        {'x': 0.6386430999999999, 'y': 0.7522124}],
#       [{'x': 0.600295, 'y': 0.36283186},
#        {'x': 0.8348082299999999, 'y': 0.7942478000000001}],
#       [{'x': 0.6917404, 'y': 0.23008850000000003},
#        {'x': 0.9557521999999999, 'y': 0.9181415999999999}],
#       [{'x': 0.47935104, 'y': 0.5376105999999999},
#        {'x': 0.5575220999999999, 'y': 0.7367256999999999}],
#       [{'x': 0.56489676, 'y': 0.5995575},
#        {'x': 0.6342183000000001, 'y': 0.7256637}],
#       [{'x': 0.6902655, 'y': 0.49115044}, {'x': 0.75516224, 'y': 0.7699115}],
#       [{'x': 0.7374630999999999, 'y': 0.5199115},
#        {'x': 0.7905605000000001, 'y': 0.7942478000000001}],
#       [{'x': 0.8097345, 'y': 0.46017700000000006},
#        {'x': 0.93510324, 'y': 0.9070796400000001}],
#       [{'x': 0.8141593, 'y': 0.44690266000000006},
#        {'x': 0.9572271000000001, 'y': 0.8738938000000002}]],
#      'number_in_dataset': 4,
#      'size_in_bytes': 273169,
#      'created_at': '2019-06-17T11:25:57.568112Z'}],
#    'quantity': 21619,
#    'size_in_bytes': 6714851753,
#    'created_at': '2019-05-26T20:18:13.721502Z',
#    'license': None,
#    'is_public': True,
#    'users_shared': [],
#    'top3_classes': [{'name': 'Mammal', 'count': 4806},
#     {'name': 'Clothing', 'count': 4683},
#     {'name': 'Person', 'count': 4394}],
#    'total_classes': 542},
#   {'id': 6,
#    'name': 'Open Images Dataset V5',
#    'image_thumbnails': [{'id': 22911,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/049366439b897151593467eec8319707?Signature=u%2B7HjE%2BLNQcA0jco2%2F3HExio6f4%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/049366439b897151593467eec8319707?Signature=4EEEGuUg81%2FSudzh1ddTtSuAyf4%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/049366439b897151593467eec8319707?Signature=jbl84CJ2EzrkUpp1MgtY8aCt974%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/049366439b897151593467eec8319707?Signature=%2Feqavl0%2BJTeaboaBnLpOJmnSLTw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '8765252d89dc40b2.jpg',
#      'dataset': {'id': 6,
#       'name': 'Open Images Dataset V5',
#       'created_at': '2019-06-24T14:05:41.183910Z',
#       'is_public': True},
#      'dataset_id': 6,
#      'dimensions': [1024, 683],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 1,
#      'size_in_bytes': 162713,
#      'created_at': '2019-06-24T15:00:54.389135Z'},
#     {'id': 22910,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/2a2c2b7613918a4c40cad3db3eb8ffb2?Signature=AcqXAU7H1FltCfjLZB9ApcJjtdo%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/2a2c2b7613918a4c40cad3db3eb8ffb2?Signature=3WFD99pPnjNPiXbiC01BOozS%2Byg%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/2a2c2b7613918a4c40cad3db3eb8ffb2?Signature=uTwgYhWc0eVSSuXd0rWBuEIAOU8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/2a2c2b7613918a4c40cad3db3eb8ffb2?Signature=Kkb9NBwFmGQL4uCRpMw5FO2AK5Q%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '3a2c1c3b54948074.jpg',
#      'dataset': {'id': 6,
#       'name': 'Open Images Dataset V5',
#       'created_at': '2019-06-24T14:05:41.183910Z',
#       'is_public': True},
#      'dataset_id': 6,
#      'dimensions': [1024, 768],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 1,
#      'size_in_bytes': 144907,
#      'created_at': '2019-06-24T15:00:54.377563Z'},
#     {'id': 22912,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/5ead618502bdf12efa2bf84e14571715?Signature=5CAaE1jNnHQ9KcS2vpBagwfQub4%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/5ead618502bdf12efa2bf84e14571715?Signature=AjWZTmmkdlyu%2B2uqAZvzoE2TuHU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/5ead618502bdf12efa2bf84e14571715?Signature=vXyvSF5OkxsOovkBcclBaJKaOVY%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/5ead618502bdf12efa2bf84e14571715?Signature=2WQlz3LxO3D8czKh2Kvn%2BimIPOw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '21d0851a96ca6250.jpg',
#      'dataset': {'id': 6,
#       'name': 'Open Images Dataset V5',
#       'created_at': '2019-06-24T14:05:41.183910Z',
#       'is_public': True},
#      'dataset_id': 6,
#      'dimensions': [1024, 685],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 2,
#      'size_in_bytes': 197871,
#      'created_at': '2019-06-24T15:00:54.403874Z'},
#     {'id': 22913,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/1845f8e1bd150daf95d416c7ebf10509?Signature=rBRCkCt90Ie0EFqCirE%2FHXBX7jk%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/1845f8e1bd150daf95d416c7ebf10509?Signature=vGxD%2ByJbL0MQin17ldnco3VEwg0%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/1845f8e1bd150daf95d416c7ebf10509?Signature=gLGEk5LEYnyH0Ew3GZsp%2BlIDdRI%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/1845f8e1bd150daf95d416c7ebf10509?Signature=oARpk2Hma74YEcSPc2NFLm0rvVU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'e022ed892f8b1e0e.jpg',
#      'dataset': {'id': 6,
#       'name': 'Open Images Dataset V5',
#       'created_at': '2019-06-24T14:05:41.183910Z',
#       'is_public': True},
#      'dataset_id': 6,
#      'dimensions': [1024, 640],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 3,
#      'size_in_bytes': 90380,
#      'created_at': '2019-06-24T15:00:54.660724Z'}],
#    'quantity': 518902,
#    'size_in_bytes': 163902000728,
#    'created_at': '2019-06-24T14:05:41.183910Z',
#    'license': None,
#    'is_public': True,
#    'users_shared': [],
#    'top3_classes': [{'name': 'Clothing', 'count': 86703},
#     {'name': 'Man', 'count': 84548},
#     {'name': 'Tree', 'count': 63793}],
#    'total_classes': 597},
#   {'id': 14,
#    'name': 'Imagenette',
#    'image_thumbnails': [{'id': 560182,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/1cedfa3a1d5b7e4ba513b1c7dabb0733?Signature=B20TOakYWcVRmvNgspRfBu4xLM8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/1cedfa3a1d5b7e4ba513b1c7dabb0733?Signature=bUNi3sjds30%2BqLI4boafNuOw%2FFY%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/1cedfa3a1d5b7e4ba513b1c7dabb0733?Signature=zPf3gY8DzLtioQRTVoqJqRLqNfU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/1cedfa3a1d5b7e4ba513b1c7dabb0733?Signature=sanUkmc3vAu2unbvoiLNY3dEdsw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'n02979186_18368.JPEG',
#      'dataset': {'id': 14,
#       'name': 'Imagenette',
#       'created_at': '2019-07-08T12:12:28.779159Z',
#       'is_public': True},
#      'dataset_id': 14,
#      'dimensions': [124, 110],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 1,
#      'size_in_bytes': 3556,
#      'created_at': '2019-08-07T07:44:00.999481Z'},
#     {'id': 560183,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/e78605a368ef52159c74ee3cd23cb361?Signature=9OouF1ROgof%2B%2BxA0WAymlnXm9Og%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/e78605a368ef52159c74ee3cd23cb361?Signature=VbDHY2i%2BoQ5QZ1nR%2FvnrOJonh2A%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/e78605a368ef52159c74ee3cd23cb361?Signature=wHtr2RyGqEvRSiVwC9wpCy9OWIE%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/e78605a368ef52159c74ee3cd23cb361?Signature=%2F7F8pFnm9H2y%2B7rTgk1QRmALi7E%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'n02979186_17940.JPEG',
#      'dataset': {'id': 14,
#       'name': 'Imagenette',
#       'created_at': '2019-07-08T12:12:28.779159Z',
#       'is_public': True},
#      'dataset_id': 14,
#      'dimensions': [350, 294],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 2,
#      'size_in_bytes': 63610,
#      'created_at': '2019-08-07T07:44:01.124442Z'},
#     {'id': 560184,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/3950799d316311973d304f3111f687b9?Signature=ubmgiaCFzZX063uJXJKwwdq5FkQ%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/3950799d316311973d304f3111f687b9?Signature=%2BHhDBlRRvqfj6gCgmSo98On2GkM%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/3950799d316311973d304f3111f687b9?Signature=dwZcBc5BYRkKiEmfVmjZVuV%2Bsm0%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/3950799d316311973d304f3111f687b9?Signature=KjvTmFlfOn4DdE4y8lTiDj%2Fq%2F7c%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'n02979186_1632.JPEG',
#      'dataset': {'id': 14,
#       'name': 'Imagenette',
#       'created_at': '2019-07-08T12:12:28.779159Z',
#       'is_public': True},
#      'dataset_id': 14,
#      'dimensions': [270, 200],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 3,
#      'size_in_bytes': 24709,
#      'created_at': '2019-08-07T07:44:01.159609Z'},
#     {'id': 560185,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/fecb5317fe8bb56e3c45146f6d034e02?Signature=IAR1Z5949x55RlbkRM28YfxkNRU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/fecb5317fe8bb56e3c45146f6d034e02?Signature=1xgQamm%2BPSpFKgk9q%2BNV1CFOCIA%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/fecb5317fe8bb56e3c45146f6d034e02?Signature=5dHcy4CfIEtMEC%2FNdX0LxqYfT%2Bo%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/fecb5317fe8bb56e3c45146f6d034e02?Signature=D5eaJ63BXod%2B1RiFhJjCGAlscJI%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'n02979186_3429.JPEG',
#      'dataset': {'id': 14,
#       'name': 'Imagenette',
#       'created_at': '2019-07-08T12:12:28.779159Z',
#       'is_public': True},
#      'dataset_id': 14,
#      'dimensions': [500, 375],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 4,
#      'size_in_bytes': 88795,
#      'created_at': '2019-08-07T07:44:01.228466Z'}],
#    'quantity': 10702,
#    'size_in_bytes': 1201332681,
#    'created_at': '2019-07-08T12:12:28.779159Z',
#    'license': None,
#    'is_public': True,
#    'users_shared': [],
#    'top3_classes': [],
#    'total_classes': 0},
#   {'id': 15,
#    'name': 'Andrea Test 2',
#    'image_thumbnails': [{'id': 546723,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/d533a5ee6315a0d355452fdfb69ec50d?Signature=RrVQh07bzTQI%2F6znm4rNmegHVEU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/d533a5ee6315a0d355452fdfb69ec50d?Signature=OUKeXJCbJeKxaHt1%2B3z8vtwfYmA%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/d533a5ee6315a0d355452fdfb69ec50d?Signature=O3kqntfrX7olefucmxgW29Bqxz8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/d533a5ee6315a0d355452fdfb69ec50d?Signature=lMebf5ArUNPVlcIp52i7jCQDgDU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '45842265_1068780183302912_8592311836822025229_n.jpg',
#      'dataset': {'id': 15,
#       'name': 'Andrea Test 2',
#       'created_at': '2019-07-10T11:56:57.558491Z',
#       'is_public': True},
#      'dataset_id': 15,
#      'dimensions': [640, 640],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 114.83601430828652, 'y': 175.34810612710675},
#        {'x': 500.7536173045412, 'y': 502.5391173630618}],
#       [{'x': 193.77398720682302, 'y': 342.51599147121533},
#        {'x': 245.62899786780383, 'y': 286.56716417910445},
#        {'x': 353.4328358208955, 'y': 292.02558635394456},
#        {'x': 397.1002132196162, 'y': 387.54797441364605},
#        {'x': 377.9957356076759, 'y': 536.2899786780383},
#        {'x': 204.69083155650318, 'y': 540.3837953091684},
#        {'x': 215.60767590618337, 'y': 403.9232409381663},
#        {'x': 193.77398720682302, 'y': 343.88059701492534}],
#       [{'x': 428.48614072494667, 'y': 163.75266524520256},
#        {'x': 549.9360341151386, 'y': 296.1194029850746},
#        {'x': 444.86140724946694, 'y': 322.046908315565},
#        {'x': 245.62899786780383, 'y': 191.04477611940297},
#        {'x': 353.4328358208955, 'y': 75.05330490405117}],
#       [{'x': 592, 'y': 471.5},
#        {'x': 503, 'y': 425.5},
#        {'x': 490, 'y': 505.5},
#        {'x': 468, 'y': 556.5},
#        {'x': 532, 'y': 583.5}]],
#      'number_in_dataset': 1,
#      'size_in_bytes': 116246,
#      'created_at': '2019-07-10T11:57:32.911265Z'},
#     {'id': 546724,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/de2ba3b7c506326a4e38b8e52991f7a9?Signature=1k2TDhqvDwJHsjXLGhOuIWlwh5w%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/de2ba3b7c506326a4e38b8e52991f7a9?Signature=JkhsUNmNkEzx5ngAakbgpvKQi1E%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/de2ba3b7c506326a4e38b8e52991f7a9?Signature=CQwFPCwUDCjmvPVFFk4YYAZJAyA%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/de2ba3b7c506326a4e38b8e52991f7a9?Signature=90HmbpuXyPiqF3UNCRfCC8eyzIs%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '6a88c33f21383a42f5f400942ee50ec3.jpg',
#      'dataset': {'id': 15,
#       'name': 'Andrea Test 2',
#       'created_at': '2019-07-10T11:56:57.558491Z',
#       'is_public': True},
#      'dataset_id': 15,
#      'dimensions': [540, 960],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 435.99147121535185, 'y': 638.63539445629},
#        {'x': 364.3496801705757, 'y': 247.67590618336888},
#        {'x': 249.7228144989339, 'y': 194.45628997867806},
#        {'x': 139.1897654584222, 'y': 382.771855010661},
#        {'x': 159.6588486140725, 'y': 726.6524520255864},
#        {'x': 350.02132196162046, 'y': 757.3560767590618},
#        {'x': 419.6162046908316, 'y': 712.3240938166311}],
#       [{'x': 149.42430703624734, 'y': 229.2537313432836},
#        {'x': 442.1321961620469, 'y': 775.7782515991471}]],
#      'number_in_dataset': 2,
#      'size_in_bytes': 94611,
#      'created_at': '2019-07-10T11:57:34.045824Z'},
#     {'id': 546725,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/6f786cb257f4d71fdf4135196ba85c19?Signature=8WYJRGM%2BQEp4Di3MYb0qTv%2BwkwU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/6f786cb257f4d71fdf4135196ba85c19?Signature=RbCrgFrvDfQ0CLlweRC2NzMQeAs%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/6f786cb257f4d71fdf4135196ba85c19?Signature=lg6RFM0pzMpA8h3SxnXDnuaqhMA%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/6f786cb257f4d71fdf4135196ba85c19?Signature=dhbv%2B%2BKTUD1ofuPU2yOe417p770%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'Lonetree_iStock-584480502-683x1024.jpg',
#      'dataset': {'id': 15,
#       'name': 'Andrea Test 2',
#       'created_at': '2019-07-10T11:56:57.558491Z',
#       'is_public': True},
#      'dataset_id': 15,
#      'dimensions': [683, 1024],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 68.8852878464819, 'y': 207.42004264392324},
#        {'x': 571.0601279317698, 'y': 574.226012793177}]],
#      'number_in_dataset': 3,
#      'size_in_bytes': 63178,
#      'created_at': '2019-07-10T11:57:35.026502Z'},
#     {'id': 546726,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/c941df22aac252d0e7c027484cf54860?Signature=00aWO19UoLl%2B7R8VLZ%2FKeyzl8k0%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/c941df22aac252d0e7c027484cf54860?Signature=7%2B08H3ApyC%2Fx98xjBphyw0YT3Lw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/c941df22aac252d0e7c027484cf54860?Signature=02AOkLd%2F5OVMWW2KvQrPUPBO4M8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/c941df22aac252d0e7c027484cf54860?Signature=y2iafIPotXr8A1HrJCpqbvLFkF4%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'edu-lauton-TyQ-0lPp6e4-unsplash.jpg',
#      'dataset': {'id': 15,
#       'name': 'Andrea Test 2',
#       'created_at': '2019-07-10T11:56:57.558491Z',
#       'is_public': True},
#      'dataset_id': 15,
#      'dimensions': [8073, 5490],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 717.5155259233634, 'y': 284.67442562493903},
#        {'x': 1167.579734189316, 'y': 769.2780605838669}]],
#      'number_in_dataset': 4,
#      'size_in_bytes': 8547506,
#      'created_at': '2019-07-18T12:11:14.548367Z'}],
#    'quantity': 4,
#    'size_in_bytes': 8821541,
#    'created_at': '2019-07-10T11:56:57.558491Z',
#    'license': None,
#    'is_public': True,
#    'users_shared': [],
#    'top3_classes': [{'name': 'dogs', 'count': 2},
#     {'name': 'dog', 'count': 1},
#     {'name': 'happy', 'count': 1}],
#    'total_classes': 3},
#   {'id': 37,
#    'name': 'Multi folders 3',
#    'image_thumbnails': [{'id': 592529,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/3960bf3d8180863a17c4a9ecd9ff2257?Signature=5qj6OqQMUV6a0KtZf9MUb2DASUU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/3960bf3d8180863a17c4a9ecd9ff2257?Signature=8sYraE%2Bw3JVNy25FpO3alAfK1dc%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/3960bf3d8180863a17c4a9ecd9ff2257?Signature=lsGBdH1%2FJhJvkorZ4cYoU8Kz2sg%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/3960bf3d8180863a17c4a9ecd9ff2257?Signature=QLs7czHAJHSUThouK4yebr%2B4AYY%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'images.jpeg',
#      'dataset': {'id': 37,
#       'name': 'Multi folders 3',
#       'created_at': '2019-08-14T14:01:58.454163Z',
#       'is_public': True},
#      'dataset_id': 37,
#      'dimensions': [275, 183],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 87, 'y': 25}, {'x': 221, 'y': 173}],
#       [{'x': 13, 'y': 82}, {'x': 56, 'y': 164}]],
#      'number_in_dataset': 1,
#      'size_in_bytes': 6970,
#      'created_at': '2019-08-14T14:01:58.483580Z'},
#     {'id': 592530,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/718b461e317ef4e799400b8c0dda5718?Signature=YCl%2FSy8OvTZ7ZifUnvXmCV9NWY8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/718b461e317ef4e799400b8c0dda5718?Signature=ZyDFsuR0%2FWFzB%2FC3D77KoEbQRJ4%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/718b461e317ef4e799400b8c0dda5718?Signature=OpS0%2FUsP2YN5mioLPzk0NLsYpU0%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/718b461e317ef4e799400b8c0dda5718?Signature=auDaJcjTTYeu%2BjmC9oK7yG1ndfQ%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'pinguin.jpg',
#      'dataset': {'id': 37,
#       'name': 'Multi folders 3',
#       'created_at': '2019-08-14T14:01:58.454163Z',
#       'is_public': True},
#      'dataset_id': 37,
#      'dimensions': [299, 199],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [],
#      'number_in_dataset': 2,
#      'size_in_bytes': 15500,
#      'created_at': '2019-08-14T14:01:58.517347Z'},
#     {'id': 592532,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/a8cb798cea5e62430646d20d9f7dc588?Signature=pes0eTX4WFOawv%2FjKhAxTBf5ShU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/a8cb798cea5e62430646d20d9f7dc588?Signature=fQpnpPIQ0vbgduflDrXn%2BSYO%2FVw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/a8cb798cea5e62430646d20d9f7dc588?Signature=jrRrluqZ5V0y9RSF8Dq4YwUBR%2B0%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/a8cb798cea5e62430646d20d9f7dc588?Signature=Etj0aJ7i3TF85r4tZ%2FWVnXNjohA%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'small-horse.jpg',
#      'dataset': {'id': 37,
#       'name': 'Multi folders 3',
#       'created_at': '2019-08-14T14:01:58.454163Z',
#       'is_public': True},
#      'dataset_id': 37,
#      'dimensions': [480, 360],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 344, 'y': 146}, {'x': 442, 'y': 112}],
#       [{'x': 157, 'y': 241}, {'x': 265, 'y': 315}],
#       [{'x': 308, 'y': 170}, {'x': 385, 'y': 242}],
#       [{'x': 183, 'y': 36}, {'x': 245, 'y': 81}]],
#      'number_in_dataset': 3,
#      'size_in_bytes': 27973,
#      'created_at': '2019-08-14T14:01:58.563548Z'},
#     {'id': 592531,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/12944b8b60c1bfd2acc405c8711e37ae?Signature=53EeVCHRpP%2BS5emvs3YGl4tJC9I%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/12944b8b60c1bfd2acc405c8711e37ae?Signature=Jw79SKL6JlhWI%2BLfhJG1WAJ90fo%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/12944b8b60c1bfd2acc405c8711e37ae?Signature=52uJ9caSgvj8994x7eaWjJVYUng%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/12944b8b60c1bfd2acc405c8711e37ae?Signature=RtuRkmOrSQhnaDeQ7PnUyPegYqw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '_99805744_gettyimages-625757214.jpg',
#      'dataset': {'id': 37,
#       'name': 'Multi folders 3',
#       'created_at': '2019-08-14T14:01:58.454163Z',
#       'is_public': True},
#      'dataset_id': 37,
#      'dimensions': [660, 371],
#      'annotates_count': 0,
#      'status': 'not_annotated',
#      'tags_count': 0,
#      'annotations_count': 0,
#      'classes': [],
#      'coordinates': [[{'x': 28, 'y': 93}, {'x': 143, 'y': 336}],
#       [{'x': 156, 'y': 45}, {'x': 562, 'y': 346}]],
#      'number_in_dataset': 3,
#      'size_in_bytes': 22235,
#      'created_at': '2019-08-14T14:01:58.535789Z'}],
#    'quantity': 20,
#    'size_in_bytes': 9216373,
#    'created_at': '2019-08-14T14:01:58.454163Z',
#    'license': None,
#    'is_public': True,
#    'users_shared': [],
#    'top3_classes': [{'name': 'person', 'count': 10},
#     {'name': 'car', 'count': 6},
#     {'name': 'cat', 'count': 6}],
#    'total_classes': 7},
#   {'id': 78,
#    'name': 'Melodi',
#    'image_thumbnails': [{'id': 1095207,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/769a4a617c5232ccd0c6d7424f060bde?Signature=zCft230hlHZ8dyW2WFiE0pSnBsE%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/769a4a617c5232ccd0c6d7424f060bde?Signature=Xp%2BZmUneOOcF%2F78W9WSbBGWXx9A%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/769a4a617c5232ccd0c6d7424f060bde?Signature=n5LxTqiwfnmCCsJURZhRjkSHFQ8%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/769a4a617c5232ccd0c6d7424f060bde?Signature=y%2BLHwx3eabrtAPGnv0E7%2B6%2BNAtU%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'dog3.jpg',
#      'dataset': {'id': 78,
#       'name': 'Melodi',
#       'created_at': '2019-10-11T07:59:49.896075Z',
#       'is_public': False},
#      'dataset_id': 78,
#      'dimensions': [375, 500],
#      'annotates_count': 1,
#      'status': '-1',
#      'tags_count': 0,
#      'annotations_count': 1,
#      'classes': [],
#      'coordinates': [[{'x': 91, 'y': 93.5}, {'x': 277, 'y': 489.5}]],
#      'number_in_dataset': 1,
#      'size_in_bytes': 38752,
#      'created_at': '2019-10-11T08:07:25.116497Z'},
#     {'id': 1095209,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/ff3b449adc2c24ea5be344060640ef40?Signature=QfJ13C2A%2F3jdhot0l0u%2B6mKpGCw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/ff3b449adc2c24ea5be344060640ef40?Signature=Tc66DUrZzRnNDgH5xvsxr1fTwZM%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/ff3b449adc2c24ea5be344060640ef40?Signature=liLG0V0%2Fy5TTlizxiX%2BfU4zYqec%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/ff3b449adc2c24ea5be344060640ef40?Signature=EUnMwTh%2BEIQ6clB2VWdHLrL4ugw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'dog2.jpg',
#      'dataset': {'id': 78,
#       'name': 'Melodi',
#       'created_at': '2019-10-11T07:59:49.896075Z',
#       'is_public': False},
#      'dataset_id': 78,
#      'dimensions': [1050, 700],
#      'annotates_count': 1,
#      'status': '-1',
#      'tags_count': 0,
#      'annotations_count': 1,
#      'classes': [],
#      'coordinates': [[{'x': 330.5248305516466, 'y': 26.41741210728774},
#        {'x': 815.8679832204214, 'y': 673.9511879463872}]],
#      'number_in_dataset': 2,
#      'size_in_bytes': 62858,
#      'created_at': '2019-10-11T08:07:25.434332Z'},
#     {'id': 1095208,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/baf1267e883c9e34bad719a192954931?Signature=614jJdFEhb5MJI3f7k%2BrwGT%2BrDY%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'thumbnail': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_thumbnails/baf1267e883c9e34bad719a192954931?Signature=4VdYuM6NPY%2BMqhusFvd99TyWXBY%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'view': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_views/baf1267e883c9e34bad719a192954931?Signature=fIJhiaZjoASPwmvdrbtatj6%2Femw%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'preview': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_previews/baf1267e883c9e34bad719a192954931?Signature=oRCNZyUaBp3k0u3mBQ4RBxHfbnI%3D&Expires=1571217305&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': 'dog1.jpg',
#      'dataset': {'id': 78,
#       'name': 'Melodi',
#       'created_at': '2019-10-11T07:59:49.896075Z',
#       'is_public': False},
#      'dataset_id': 78,
#      'dimensions': [750, 500],
#      'annotates_count': 1,
#      'status': '-1',
#      'tags_count': 0,
#      'annotations_count': 1,
#      'classes': [],
#      'coordinates': [[{'x': 341, 'y': 95.5}, {'x': 616, 'y': 467.5}]],
#      'number_in_dataset': 2,
#      'size_in_bytes': 61245,
#      'created_at': '2019-10-11T08:07:25.434053Z'}],
#    'quantity': 3,
#    'size_in_bytes': 162855,
#    'created_at': '2019-10-11T07:59:49.896075Z',
#    'license': None,
#    'is_public': False,
#    'users_shared': [],
#    'top3_classes': [{'name': 'Dog', 'count': 3}],
#    'total_classes': 1}]}

# %% [markdown]
# ### To be expanded upon - list images in a dataset, each with its own class

# %%
my_dataset.images
# Out:
# [<remo.domain.dataset.Image at 0x1c110fa2780>,
#  <remo.domain.dataset.Image at 0x1c110fa2fd0>,
#  <remo.domain.dataset.Image at 0x1c110fa29b0>]

# %%
my_dataset.list_images()
# Out:
# Next: None
# ['dog3.jpg', 'dog2.jpg', 'dog1.jpg']

# %%
img_urls = my_dataset.get_images()

# %%
img_urls
# Out:
# ['https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/769a4a617c5232ccd0c6d7424f060bde?Signature=KT0ccW0uw6hhDd0dSWaQJ07lPq0%3D&Expires=1571217211&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#  'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/ff3b449adc2c24ea5be344060640ef40?Signature=c%2F1atNkVGJiwLN0cdIf4whjDfF4%3D&Expires=1571217211&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#  'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/baf1267e883c9e34bad719a192954931?Signature=%2FRA%2Fw3T3Ph2MrqmkdSRdfwNi4u8%3D&Expires=1571217211&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ']

# %%
img_list = my_dataset.show_images()

# %%
img_list
# Out:
# [<_io.BytesIO at 0x1c50aa4fdb0>,
#  <_io.BytesIO at 0x1c509219518>,
#  <_io.BytesIO at 0x1c50ab0b9e8>]

# %%
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(15, 15))
columns = 2
rows = round((len(img_list) + 1)/columns)
i = 1
for img in img_list:
    fig.add_subplot(rows, columns, i)
    image = Image.open(img)
    plt.imshow(image)
    i += 1
