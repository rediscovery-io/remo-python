# %%
#db = PostgresqlExtDatabase('devremo', user='devremo', password='ksf03jfs0df9uj32pro',host='35.197.222.72', port=5432,
  #                        autocommit=True, autorollback=True)

from peewee import SqliteDatabase
db_path = 'C:/Users/Andrea.LaRosa/.remo/remo_db.sqlite3'
db = SqliteDatabase(db_path, autocommit=True, autorollback=True)

# %load_ext autoreload
# %autoreload 2
import remo

# %% [markdown]
# Why did it ask to login?

# %%
db

# %%
sdk = remo.SDK('http://localhost:8000','admin@remo.ai', 'adminpass')
sdk.list_datasets()
# Out:
# [{'id': 3, 'license_id': None, 'name': 'dataset test: imagenet'},
#  {'id': 5, 'license_id': None, 'name': 'local_test'},
#  {'id': 7, 'license_id': None, 'name': 'local_test_2'},
#  {'id': 9, 'license_id': None, 'name': 'litho_test'},
#  {'id': 11, 'license_id': None, 'name': 'litho_test'},
#  {'id': 13, 'license_id': None, 'name': 'litho_test'},
#  {'id': 17, 'license_id': None, 'name': 'litho_test'},
#  {'id': 21, 'license_id': None, 'name': 'litho_test'},
#  {'id': 22, 'license_id': None, 'name': 'litho_test'},
#  {'id': 23, 'license_id': None, 'name': 'litho_test'},
#  {'id': 24, 'license_id': None, 'name': 'litho_test'},
#  {'id': 25, 'license_id': None, 'name': 'litho_test'},
#  {'id': 26, 'license_id': None, 'name': 'litho_test'},
#  {'id': 27, 'license_id': None, 'name': 'litho_test'},
#  {'id': 28, 'license_id': None, 'name': 'litho_test'},
#  {'id': 29, 'license_id': None, 'name': 'litho_test'},
#  {'id': 30, 'license_id': None, 'name': 'litho_test'},
# ...

# %%
my_dataset = sdk.create_dataset('litho_test_new')
my_dataset
# Out:
# {'license': None, 'top3_classes': [], 'annotation_sets': [], 'id': 33, 'total_annotation_objects': 0, 'total_classes': 0, 'users_shared': [], 'created_at': '2019-10-17T10:13:34.065197Z', 'is_public': False, 'name': 'litho_test_new'}
# Dataset 33 - 'litho_test_new'

# %%
import glob
images_path = 'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/images/'
images_path = 'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/'
#images_path = 'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/'
images_list = glob.glob(images_path + '*')
images_list
# Out:
# ['C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test\\lithography02_0000.png',
#  'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test\\lithography02_0001.png',
#  'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test\\lithography02_0002.png']

# %% [markdown]
# chunks = 2000

# %%
images_list =  ['C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0000.png', 'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0001.png', 'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0002.png']
images_list
# Out:
# ['C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0000.png',
#  'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0001.png',
#  'C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/lithography02_0002.png']

# %%
sdk.add_data_to_dataset(3, paths_to_add=['C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/small_test/'])
# Out:
# Possible Error - Response:
#
#
#
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>remo.ai</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800&amp;subset=cyrillic" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet">
#     <link rel="shortcut icon" href="/static/images/favicon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="/static/images/favicon.png">
#     <!-- Tell the browser to be responsive to screen width -->
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#
#
#       <link rel="stylesheet" href="/static/dist/styles.css">
#
#   </head>
#
#   <body>
#
#     <div id="app">Loading...</div>
#
#
#       <script src="/static/dist/bundle.js"></script>
#
#
#
#
#
#   </body>
# </html>
# ...

# %%
def upload_files(dataset_id: int, 
                 paths_to_add: list, 
                 paths_to_upload: list, 
                 annotation_task: AnnotationTask = None,
                 folder_id: int = None, 
                 status: UploadStatus = None):

    files = [('files', (os.path.basename(path), open(path, 'rb'), filetype.guess_mime(path))) for path in paths_to_upload]


    data = {'local_files': paths_to_add }
    if annotation_task:
        data['annotation_task'] = annotation_task.value

    url = self.url('/api/dataset/{}/upload'.format(dataset_id), folder_id=folder_id)
    r = self.post(url, files=files, data=data)

    if r.status_code != http.HTTPStatus.OK:
        print('Possible Error - Response:', r.text, 'files:', paths_to_add)

    #status.update(len(paths_to_upload))
    #status.progress()
    return r.json()

# %%
my_dataset = remo.sdk.Dataset()

# %%
api = remo.api.API('http://localhost:8000')
api.login('admin@remo.ai', 'adminpass')

# %%
import os
import filetype
files = [('files', (os.path.basename(path), open(path, 'rb'), filetype.guess_mime(path))) for path in images_list[0:10]]

# %%
files[0]
# Out:
# ('files',
#  ('lithography02_0000.png',
#   <_io.BufferedReader name='C:/Users/Andrea.LaRosa/Desktop/Projects/Lithologs/Data/Synthetic data assets/Generated data/Lithography PoC3/images\\lithography02_0000.png'>,
#   'image/png'))

# %%
api.upload_files(dataset_id = 3, paths_to_add =  images_list[:10])
# Out:
# Possible Error - Response:
#
#
#
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>remo.ai</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800&amp;subset=cyrillic" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet">
#     <link rel="shortcut icon" href="/static/images/favicon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="/static/images/favicon.png">
#     <!-- Tell the browser to be responsive to screen width -->
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#
#
#       <link rel="stylesheet" href="/static/dist/styles.css">
#
#   </head>
#
#   <body>
#
#     <div id="app">Loading...</div>
#
#
#       <script src="/static/dist/bundle.js"></script>
#
#
#
#
#
#   </body>
# </html>
# ...

# %%
my_dataset.add_data(paths_to_add=images_list[:4000])
# Out:
# Possible Error - Response:
#
#
#
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>remo.ai</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800&amp;subset=cyrillic" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet">
#     <link rel="shortcut icon" href="/static/images/favicon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="/static/images/favicon.png">
#     <!-- Tell the browser to be responsive to screen width -->
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#
#
#       <link rel="stylesheet" href="/static/dist/styles.css">
#
#   </head>
#
#   <body>
#
#     <div id="app">Loading...</div>
#
#
#       <script src="/static/dist/bundle.js"></script>
#
#
#
#
#
#   </body>
# </html>
# ...

# %% [markdown]
# chunks = 1000, 2 workers

# %%
my_dataset.add_data(files=images_list[:2000])
# Out:
# Possible Error - Response:
#
#
#
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>remo.ai</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800&amp;subset=cyrillic" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Montserrat" rel="stylesheet">
#     <link rel="shortcut icon" href="/static/images/favicon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="/static/images/favicon.png">
#     <!-- Tell the browser to be responsive to screen width -->
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#
#
#       <link rel="stylesheet" href="/static/dist/styles.css">
#
#   </head>
#
#   <body>
#
#     <div id="app">Loading...</div>
#
#
#       <script src="/static/dist/bundle.js"></script>
#
#
#
#
#
#   </body>
# </html>
# ...

# %% [markdown]
# chunks = 500

# %%
my_dataset.add_data(files=images_list)
# Out:
# Progress 2% - 500/20000 - elapsed 0:02:14.001000 - speed: 3.73 img / s, ETA: 1:27:06.039000
# Progress 5% - 1000/20000 - elapsed 0:03:26.001000 - speed: 4.85 img / s, ETA: 1:05:14.019000
# Progress 7% - 1500/20000 - elapsed 0:04:40.001000 - speed: 5.36 img / s, ETA: 0:57:33.345667
# Progress 10% - 2000/20000 - elapsed 0:05:57.001000 - speed: 5.60 img / s, ETA: 0:53:33.009000
# Progress 12% - 2500/20000 - elapsed 0:07:16.001000 - speed: 5.73 img / s, ETA: 0:50:52.007000
# Progress 15% - 3000/20000 - elapsed 0:08:35.001000 - speed: 5.83 img / s, ETA: 0:48:38.339000
# Progress 17% - 3500/20000 - elapsed 0:09:52.001000 - speed: 5.91 img / s, ETA: 0:46:30.861857
# Progress 20% - 4000/20000 - elapsed 0:11:11.001000 - speed: 5.96 img / s, ETA: 0:44:44.004000
# Progress 22% - 4500/20000 - elapsed 0:12:28.001000 - speed: 6.02 img / s, ETA: 0:42:56.447889
# Progress 25% - 5000/20000 - elapsed 0:13:48.001000 - speed: 6.04 img / s, ETA: 0:41:24.003000
# ...

# %% [markdown]
# chunks = 1000

# %%
my_dataset.add_data(files=images_list)
# Out:
# Progress 5% - 1000/20000 - elapsed 0:02:27.001000 - speed: 6.80 img / s, ETA: 0:46:33.019000
# Progress 10% - 2000/20000 - elapsed 0:04:54.001000 - speed: 6.80 img / s, ETA: 0:44:06.009000

# %%
import os

def split_files_on_groups(self, files: list) -> list:
    groups = []
    bulk = []
    total_size = 0
    bulk_size = 8 * 1024 * 1024
    for path in files:
        total_size += os.path.getsize(path)
        bulk.append(path)
        if total_size >= bulk_size:
            groups.append(bulk)
            bulk = []
            total_size = 0

    if len(bulk):
        groups.append(bulk)
    return groups

# %%
groups = split_files_on_groups(2,images_list)

# %%
def chunks(my_list, chunk_size):
    groups = []
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(my_list), chunk_size):
        groups.append(my_list[i:i + chunk_size])
        
    return groups

# %%
groups = chunks(images_list, 1000)

# %%
len(groups)
# Out:
# 20

# %%
len(groups[0])
# Out:
# 21

# %%
my_dataset.add_data(files=images_list)
# Out:
# Progress 1% - 211/20000 - elapsed 0:00:45.001000 - speed: 4.69 img / s, ETA: 1:10:20.496630
# Progress 2% - 404/20000 - elapsed 0:01:24.001000 - speed: 4.81 img / s, ETA: 1:07:54.464347
# Progress 3% - 617/20000 - elapsed 0:02:08.001000 - speed: 4.82 img / s, ETA: 1:07:01.140005
# Progress 4% - 809/20000 - elapsed 0:02:48.001000 - speed: 4.82 img / s, ETA: 1:06:25.299371
# Progress 5% - 1019/20000 - elapsed 0:03:35.001000 - speed: 4.74 img / s, ETA: 1:06:44.841983
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-33-4dbc31cde495> in <module>()
# ----> 1 my_dataset.add_data(files=images_list)
#
# ~\Desktop\Projects\repo\rem_repo\local_remo-python\remo\domain\dataset.py in add_data(self, files, urls, annotation_task, folder_id)
#     102         """
#     103
# --> 104         return self.sdk.add_data_to_dataset(self.id, files, urls, annotation_task, folder_id)
# ...

# %%
len(images_path)
# Out:
# 116

# %%
import os, glob
my_dir = 'C:/Users/Andrea.LaRosa/Desktop/Projects/rem/Data/PennFudanPed/PNGImages/'
files = glob.glob(my_dir + '*')
files

# %%
sdk = remo.SDK('https://dev.remo.ai','admin@remo.ai', 'grunerBox')
sdk.list_datasets()
# Out:
# [{'id': 3, 'license_id': None, 'name': 'Open Images V5'},
#  {'id': 4, 'license_id': None, 'name': 'Multi folders 3'},
#  {'id': 6, 'license_id': None, 'name': 'Open Images Dataset V5'},
#  {'id': 7, 'license_id': None, 'name': 'test andra'},
#  {'id': 14, 'license_id': None, 'name': 'Imagenette'},
#  {'id': 15, 'license_id': None, 'name': 'Andrea Test 2'},
#  {'id': 17, 'license_id': None, 'name': 'Images'},
#  {'id': 18, 'license_id': None, 'name': 'Im'},
#  {'id': 19, 'license_id': None, 'name': 'asim'},
#  {'id': 35, 'license_id': None, 'name': 'Open Images V5'},
#  {'id': 36, 'license_id': None, 'name': 'COCO 2'},
#  {'id': 37, 'license_id': None, 'name': 'Multi folders 3'},
#  {'id': 61, 'license_id': None, 'name': 'Andrea Test2'},
#  {'id': 64, 'license_id': None, 'name': 'Sample'},
#  {'id': 65, 'license_id': None, 'name': 'LargeOne'},
#  {'id': 70, 'license_id': None, 'name': 'Demo: imagenet'},
#  {'id': 75, 'license_id': None, 'name': 'dataset test: imagenet'},
# ...

# %%
my_dataset = sdk.get_dataset(19)
# Out:
# Next: None

# %%
my_dataset.images

# %%
api = remo.api.API('https://dev.remo.ai')
api.login('admin@remo.ai', 'grunerBox')

# %%
url = api.url('api/v1/ui/datasets/19/images/562896/annotations/')
tt = api.get(url).json()
tt
# Out:
# {'annotations': [{'annotation_set': {'id': 53,
#     'name': 'Animals',
#     'task': 'Object detection'},
#    'classes': {'Bear': 1, 'Cat': 1},
#    'objects': [{'classes': ['Bear'],
#      'coordinates': [{'x': 830, 'y': 162.5}, {'x': 1020, 'y': 329.5}],
#      'id': 2787634,
#      'name': 'OBJ 3'},
#     {'classes': ['Cat'],
#      'coordinates': [{'x': 131.3390191897655, 'y': 67.3560767590618},
#       {'x': 703.4802229597829, 'y': 450.0446656217133}],
#      'id': 2787633,
#      'name': 'OBJ 2'}],
#    'tags': []}],
#  'dataset': {'created_at': '2019-08-01T14:40:30.603415Z',
#   'id': 19,
#   'is_public': False,
#   'name': 'asim'},
#  'dimensions': [1100, 619],
#  'id': 562896,
#  'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/6953743507b2899d4cebfd1fc8f69dc7?Signature=VCnTK1rohZjYfAHCiNAoSCv1Yew%3D&Expires=1570544253&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#  'name': '549585-istock-909106260.jpg',
#  'skipped': False,
# ...

# %%
url = api.url('/api/v1/ui/datasets/19/annotation-sets'.format(19))

tt = api.get(url).json()
tt['results'][0]
# Out:
# {'id': 32,
#  'is_completed': False,
#  'is_public': False,
#  'last_annotated_date': '2019-10-07T15:55:56.607415Z',
#  'name': 'Classification',
#  'released_at': None,
#  'statistics': {'annotated_images_count': 12,
#   'top3_classes': [],
#   'total_annotation_objects': 0,
#   'total_classes': 0},
#  'task': {'id': 3,
#   'name': 'Image classification',
#   'type': 'image_classification'},
#  'total_images': 26,
#  'updated_at': '2019-10-07T15:55:56.608832Z'}

# %%
api.list_datasets()
# Out:
# {'count': 9,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2019-05-26T20:18:13.721502Z',
#    'id': 3,
#    'image_thumbnails': [{'annotates_count': 1,
#      'annotations_count': 1,
#      'classes': [],
#      'coordinates': [[{'x': 37.663113006396586, 'y': 127.72707889125799},
#        {'x': 998.8912579957358, 'y': 671.3859275053305}]],
#      'created_at': '2019-06-17T11:25:57.568112Z',
#      'dataset': {'created_at': '2019-05-26T20:18:13.721502Z',
#       'id': 3,
#       'is_public': True,
#       'name': 'Open Images V5'},
#      'dataset_id': 3,
#      'dimensions': [1024, 768],
#      'id': 6,
#      'image': 'https://s3-eu-west-1.amazonaws.com:443/dev-remo-media/media/dataset_images/ed5b074d0ae1e020a661727851f9d7c9?Signature=QrUUg20CjrExVzN%2FIgc%2Flz7hqcM%3D&Expires=1570610615&AWSAccessKeyId=AKIAS4EN6CYR2LFIMNEJ',
#      'name': '13640a5069c55171.jpg',
#      'number_in_dataset': 1,
# ...

# %%
api.

# %%
url = api.url('api/dataset/19/annotation-set/53/image/562896/annotation/')
tt = api.get(url).json()
tt
# Out:
# {'annotation_info': [{'auto_created': False,
#    'classes': [{'lower': 'cat', 'name': 'Cat', 'questionable': False}],
#    'coordinates': [{'x': 131.3390191897655, 'y': 67.3560767590618},
#     {'x': 703.4802229597829, 'y': 450.0446656217133}],
#    'name': 'OBJ 2',
#    'position_number': 1},
#   {'auto_created': False,
#    'classes': [{'lower': 'bear', 'name': 'Bear', 'questionable': False}],
#    'coordinates': [{'x': 830, 'y': 162.5}, {'x': 1020, 'y': 329.5}],
#    'name': 'OBJ 3',
#    'position_number': 2}],
#  'error': False,
#  'skipped': False}

# %%
tt = api.get_dataset(19)
tt
# Out:
# {'annotation_sets': [32, 53, 75],
#  'created_at': '2019-08-01T14:40:30.603415Z',
#  'id': 19,
#  'is_public': False,
#  'license': None,
#  'name': 'asim',
#  'top3_classes': [{'count': 4, 'name': 'Dog'},
#   {'count': 3, 'name': 'Bear'},
#   {'count': 2, 'name': 'Cat'}],
#  'total_annotation_objects': 24,
#  'total_classes': 6,
#  'users_shared': []}

# %%
api.anno
# Out:
# {'annotation_sets': [32, 53, 75],
#  'created_at': '2019-08-01T14:40:30.603415Z',
#  'id': 19,
#  'is_public': False,
#  'license': None,
#  'name': 'asim',
#  'top3_classes': [{'count': 4, 'name': 'Dog'},
#   {'count': 3, 'name': 'Bear'},
#   {'count': 2, 'name': 'Cat'}],
#  'total_annotation_objects': 24,
#  'total_classes': 6,
#  'users_shared': []}

# %%
#sdk = remo.SDK('https://dev.remo.ai', 'andrea@remo.ai', 'AndRemo123!')
sdk = remo.SDK("https://dev.remo.ai", 'admin@remo.ai','grunerBox')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f573e56f48fd> in <module>()
#       1 #sdk = remo.SDK('https://dev.remo.ai', 'andrea@remo.ai', 'AndRemo123!')
# ----> 2 sdk = remo.SDK("https://dev.remo.ai", 'admin@remo.ai','grunerBox')
#
# NameError: name 'remo' is not defined

# %%
my_dat

# %%
my_datasets = sdk.list_datasets()
my_datasets
# Out:
# [Dataset 3 - 'Open Images V5',
#  Dataset 4 - 'Multi folders 3',
#  Dataset 6 - 'Open Images Dataset V5',
#  Dataset 14 - 'Imagenette',
#  Dataset 15 - 'Andrea Test 2',
#  Dataset 19 - 'asim',
#  Dataset 37 - 'Multi folders 3',
#  Dataset 75 - 'dataset test: imagenet',
#  Dataset 76 - 'dataset test: imagenet']

# %%
my_dataset = sdk.get_dataset(19)
my_dataset
# Out:
# Next: None
# Screen Shot 2019-08-05 at 7.49.12 PM.png asim
# Screen Shot 2019-08-04 at 4.08.23 PM.png asim
# images.jpeg asim
# petmd-cat-happy-13.jpg asim
# 549585-istock-909106260.jpg asim
# _99805744_gettyimages-625757214.jpg asim
# COCO_val2014_000000391895.jpg asim
# COCO_val2014_000000522418.jpg asim
# COCO_val2014_000000184613.jpg asim
# COCO_val2014_000000318219.jpg asim
# COCO_val2014_000000554625.jpg asim
# COCO_val2014_000000397133.jpg asim
# COCO_val2014_000000574769.jpg asim
# COCO_val2014_000000060623.jpg asim
# COCO_val2014_000000309022.jpg asim
# COCO_val2014_000000005802.jpg asim
# ILSVRC2012_val_00000003.JPEG asim
# ILSVRC2012_val_00000008.JPEG asim
# ILSVRC2012_val_00000006.JPEG asim
# ILSVRC2012_val_00000001.JPEG asim
# ILSVRC2012_val_00000007.JPEG asim
# ILSVRC2012_val_00000010.JPEG asim
# ILSVRC2012_val_00000005.JPEG asim
# ILSVRC2012_val_00000011.JPEG asim
# ILSVRC2012_val_00000009.JPEG asim
# ILSVRC2012_val_00000002.JPEG asim
# Dataset 19 - 'asim'

# %%
tt = my_dataset.images[1]

# %%
my_dataset.created_at
# Out:
# '2019-08-01T14:40:30.603415Z'

# %% [markdown]
# **3) dataset = create_dataset()**

# %%
dataset = sdk.create_dataset(name = 'dataset test: imagenet',
                            urls=["https://remo-sample-datasets.s3-eu-west-1.amazonaws.com/Imagenet_sample_dataset.zip"],
                            annotation_task=remo.AnnotationTask.image_classification)
dataset
# Out:
# {'id': 31, 'annotation_sets': [], 'total_classes': 0, 'license': None, 'top3_classes': [], 'is_public': False, 'name': 'dataset test: imagenet', 'users_shared': [], 'total_annotation_objects': 0, 'created_at': '2019-10-04T16:08:24.085438Z'}
# {'jobs': [{'job_id': 'e5557c74-4309-4308-b1c2-777355084a7f', 'status': 'queued'}]}
# Dataset 31 - 'dataset test: imagenet'

# %%
dataset.browse()
# Out:
# Open https://remo.ai/datasets/31

# %% [markdown]
# **4) add data to your dataset**

# %%
sdk.add_data_to_dataset(19, urls=["https://remo-sample-datasets.s3-eu-west-1.amazonaws.com/Imagenet_sample_dataset.zip"],
               annotation_task=remo.AnnotationTask.image_classification)
# Out:
# {'jobs': [{'status': 'queued', 'job_id': 'c15c262a-ed60-4488-88ce-8e683d7a1390'}]}
# {'urls_upload_result': {'jobs': [{'job_id': 'c15c262a-ed60-4488-88ce-8e683d7a1390',
#     'status': 'queued'}]}}

# %%
dataset.browse()
# Out:
# Open https://dev.remo.ai/datasets/74

# %% [markdown]
# ** 5) Annotation statistics **

# %%
my_dataset = sdk.get_dataset(19)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7ad876d9682c> in <module>()
# ----> 1 my_dataset = sdk.get_dataset(19)
#
# ~\Desktop\Projects\repo\rem_repo\remo-python\remo\sdk.py in get_dataset(self, dataset_id)
#      52         '''
#      53         result = self.api.get_dataset(dataset_id)
# ---> 54         return Dataset(self, **result)
#      55
#      56     def add_data_to_dataset(self, dataset_id, files=[], urls=[], annotation_task=None, folder_id=None):
#
# ~\Desktop\Projects\repo\rem_repo\remo-python\remo\domain\dataset.py in __init__(self, sdk, **kwargs)
#      49         if 'id' in kwargs:
#      50            self.id = kwargs.get('id')
# ---> 51            self.initiailise_images()
#      52
#      53         self.name = kwargs.get('name')
#
# AttributeError: 'Dataset' object has no attribute 'initiailise_images'

# %%
my_dataset.ann_statistics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-968d00eb1783> in <module>()
# ----> 1 my_dataset.ann_statistics()
#
# ~\Desktop\Projects\repo\rem_repo\remo-python\remo\domain\dataset.py in ann_statistics(self)
#      97         # we won't need this after arranging endpoints
#      98       #  con = psycopg2.connect(database=.., user=.., password=.. host=.., port=..)
# ---> 99         cur = con.cursor()
#     100         query = "SELECT t.* FROM public.annotation_set_statistics t where dataset_id = %s"
#     101         cur.execute(query % self.id)
#
# NameError: name 'con' is not defined

# %% [markdown]
# Annotation sets

# %%
sdk.list_annotation_sets(19)
# Out:
# {'count': 3,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 32,
#    'is_completed': False,
#    'is_public': False,
#    'last_annotated_date': '2019-10-07T15:55:56.607415Z',
#    'name': 'Classification',
#    'released_at': None,
#    'statistics': {'annotated_images_count': 12,
#     'top3_classes': [],
#     'total_annotation_objects': 0,
#     'total_classes': 0},
#    'task': {'id': 3,
#     'name': 'Image classification',
#     'type': 'image_classification'},
#    'total_images': 26,
#    'updated_at': '2019-10-07T15:55:56.608832Z'},
#   {'id': 53,
#    'is_completed': False,
#    'is_public': False,
#    'last_annotated_date': '2019-10-07T14:36:06.482598Z',
#    'name': 'Animals',
#    'released_at': None,
#    'statistics': {'annotated_images_count': 2,
#     'top3_classes': [{'count': 2, 'name': 'Bear'},
#      {'count': 1, 'name': 'Dog'},
#      {'count': 1, 'name': 'Cat'}],
#     'total_annotation_objects': 15,
#     'total_classes': 3},
# ...

# %%
sdk.all_info_datasets()
# Out:
# {'count': 4,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2019-08-27T16:14:44.478511Z',
#    'id': 9,
#    'image_thumbnails': [{'annotates_count': 1,
#      'annotations_count': 1,
#      'classes': [],
#      'coordinates': [[{'x': 193, 'y': 95.20000076293945},
#        {'x': 352, 'y': 235.1999969482422},
#        {'x': 284, 'y': 276.1999969482422},
#        {'x': 201, 'y': 240.1999969482422},
#        {'x': 165, 'y': 174.1999969482422},
#        {'x': 215, 'y': 169.1999969482422}]],
#      'created_at': '2019-08-27T16:15:52.129589Z',
#      'dataset': {'created_at': '2019-08-27T16:14:44.478511Z',
#       'id': 9,
#       'is_public': False,
#       'name': 'test'},
#      'dataset_id': 9,
#      'dimensions': [624, 351],
#      'id': 2197483,
# ...

# %%
my_dataset.images
# Out:
# []

# %%
dataset.id = 18

# %%
dataset.images(24, limit = 10000)
# Out:
# Next: None
# ['n02979186_18368.JPEG',
#  'n02979186_13873.JPEG',
#  'n02979186_14304.JPEG',
#  'n02979186_7531.JPEG',
#  'n02979186_1632.JPEG',
#  'n02979186_3429.JPEG',
#  'n02979186_13206.JPEG',
#  'n02979186_17940.JPEG',
#  'n02979186_2774.JPEG',
#  'n02979186_465.JPEG',
#  'n02979186_16422.JPEG',
#  'n02979186_1823.JPEG',
#  'n02979186_12598.JPEG',
#  'n02979186_7743.JPEG',
#  'n02979186_15298.JPEG',
#  'n02979186_12590.JPEG',
#  'n02979186_14197.JPEG',
#  'n02979186_11410.JPEG',
#  'n02979186_3279.JPEG',
#  'n02979186_9910.JPEG',
#  'n02979186_10532.JPEG',
#  'n02979186_1397.JPEG',
#  'n02979186_2587.JPEG',
#  'n02979186_357.JPEG',
#  'n02979186_2265.JPEG',
#  'n02979186_1198.JPEG',
#  'n02979186_4447.JPEG',
#  'n02979186_21725.JPEG',
#  'n02979186_2516.JPEG',
#  'n02979186_26802.JPEG',
#  'n02979186_2718.JPEG',
#  'n02979186_4375.JPEG',
#  'n02979186_2642.JPEG',
#  'n02979186_3182.JPEG',
#  'n02979186_12193.JPEG',
#  'n02979186_4266.JPEG',
#  'n02979186_26475.JPEG',
# ...

# %%
dataset.images(24)
# Out:
# Next: http://dev.remo.ai/api/user-dataset/18/contents/24/?limit=32&offset=32
# ['n02979186_18368.JPEG',
#  'n02979186_14304.JPEG',
#  'n02979186_13873.JPEG',
#  'n02979186_7531.JPEG',
#  'n02979186_1632.JPEG',
#  'n02979186_3429.JPEG',
#  'n02979186_13206.JPEG',
#  'n02979186_17940.JPEG',
#  'n02979186_2774.JPEG',
#  'n02979186_465.JPEG',
#  'n02979186_16422.JPEG',
#  'n02979186_1823.JPEG',
#  'n02979186_12598.JPEG',
#  'n02979186_15298.JPEG',
#  'n02979186_7743.JPEG',
#  'n02979186_12590.JPEG',
#  'n02979186_14197.JPEG',
#  'n02979186_11410.JPEG',
#  'n02979186_3279.JPEG',
#  'n02979186_9910.JPEG',
#  'n02979186_10532.JPEG',
#  'n02979186_1397.JPEG',
#  'n02979186_2587.JPEG',
#  'n02979186_357.JPEG',
#  'n02979186_2265.JPEG',
#  'n02979186_1198.JPEG',
#  'n02979186_4447.JPEG',
#  'n02979186_21725.JPEG',
#  'n02979186_2516.JPEG',
#  'n02979186_26802.JPEG',
#  'n02979186_2718.JPEG',
#  'n02979186_4375.JPEG']

# %%
dataset.images(88)
# Out:
# Next: None
# ['ILSVRC2012_val_00000008.JPEG',
#  'ILSVRC2012_val_00000003.JPEG',
#  'ILSVRC2012_val_00000010.JPEG',
#  'ILSVRC2012_val_00000006.JPEG',
#  'ILSVRC2012_val_00000007.JPEG',
#  'ILSVRC2012_val_00000005.JPEG',
#  'ILSVRC2012_val_00000011.JPEG',
#  'ILSVRC2012_val_00000001.JPEG',
#  'ILSVRC2012_val_00000009.JPEG',
#  'ILSVRC2012_val_00000002.JPEG']

# %%
class AnnotationSet:
    id = None
    dataset = None
    task = None
    name = None
    classes = None
    
    def __init__(self,, sdk, **kwargs):
        self.dataset = dataset
        self.name = kwargs.get('name')
        self.id = kwargs.get('id')
        self.task = kwargs.get('task')
        self.classes = kwargs.get('classes')

    def annotations(self, images=None) -> [Annotation]:
        if not images:
            return api.get_annotations(self.dataset.id, self.id)
        image_ids = []
        if type(images) == list:
            image_ids = [img.id for img in images]
        elif type(images) == Image:
            image_ids = [images.id]
        return api.get_annotations(self.dataset.id, self.id, image_ids)
    
class Annotation:
    id = None
    dataset_id = None
    image_id = None
    annotation_set_id = None
    data = {}

# %%
api = remo.api.API('https://remo.ai')
api.login('email', 'pwd')

# %%
url = api.url('/api/v1/ui/datasets/{}/annotation-sets'.format(19))
api.get(url).json()
# Out:
# {'count': 3,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 32,
#    'is_completed': False,
#    'is_public': False,
#    'last_annotated_date': '2019-08-07T05:05:24.510102Z',
#    'name': 'Classification',
#    'released_at': None,
#    'statistics': {'annotated_images_count': 2,
#     'top3_classes': [],
#     'total_annotation_objects': 0,
#     'total_classes': 0},
#    'task': {'id': 3,
#     'name': 'Image classification',
#     'type': 'image_classification'},
#    'total_images': 16,
#    'updated_at': '2019-08-07T05:05:24.510227Z'},
#   {'id': 53,
#    'is_completed': False,
#    'is_public': False,
#    'last_annotated_date': '2019-09-27T16:03:49.276910Z',
#    'name': 'Animals',
#    'released_at': None,
#    'statistics': {'annotated_images_count': 2,
#     'top3_classes': [{'count': 1, 'name': 'Bear'},
#      {'count': 1, 'name': 'Dog'},
#      {'count': 1, 'name': 'Cat'}],
#     'total_annotation_objects': 14,
#     'total_classes': 3},
# ...

# %%
class Dataset(object):
    r"""An abstract class representing a :class:`Dataset`.

    All datasets that represent a map from keys to data samples should subclass
    it. All subclasses should overrite :meth:`__getitem__`, supporting fetching a
    data sample for a given key. Subclasses could also optionally overwrite
    :meth:`__len__`, which is expected to return the size of the dataset by many
    :class:`~torch.utils.data.Sampler` implementations and the default options
    of :class:`~torch.utils.data.DataLoader`.

    .. note::
      :class:`~torch.utils.data.DataLoader` by default constructs a index
      sampler that yields integral indices.  To make it work with a map-style
      dataset with non-integral indices/keys, a custom sampler must be provided.
    """

    def __getitem__(self, index):
        raise NotImplementedError("All dataset instances should have a __get__item function implemented")

    def __add__(self, other):
        return ConcatDataset([self, other])

# %% [markdown]
# add comments on methods

# %%
class remo_Dataset(Dataset):

    def __init__(self, sdk, **kwargs):
        self.sdk = sdk
        self.name = kwargs.get('name')
        self.id = kwargs.get('id')
        self.license = kwargs.get('license')
        
        self.data = connect_to_daset
        
    def __str__(self):
        return 'Dataset (id={}, name={})'.format(self.id, self.name)
    
    def __getitem__(self, idx)
        
        img_path = self.data[idx]
        image = io.imread(img_path)
        
        return self.data[index]

    def add_data(images_data = , 
                annotation_data = , 
                annotation_task = ,
                annotation_format = )
        '''
        Functionalities:
        - adds images from local disk to the db
        - optional, add annotation corresponding to those images
        - annotation: support for annotation for different tasks and formats
        
        - prints summary of the data add:
            - number of images added
            - recognised tasks
            - statistics on annotations uploaded (number of )
            
        Returns:
        - nothing
        
        '''
        return 
    
    def browse(self):
        utils.browse(self.sdk.ui.dataset_url(self.id))
        
    def search
    
        return sub_dataset
    
    def view_images(self, indices_or_sub_dataset, class_name = None, annotation_set = None)
    
        show_images_in_ui
        
    def view_objects(self, indices_or_sub_dataset)
    
    
    class Annotation_set:
        
        def __init__(self, annotation_task = None, annotation_set_name = None):
            self.annotation_task = annotation_task
            self.annotation_set_name = annotation_set_name

# %%
tt = remo_Dataset(sdk, name = "dogs")

# %% [markdown]
# - get_items()
# - get_images()
# - show_images()
# - show_objects()

# %% [markdown]
# - dataset.annotation_set = dataset.create_annotation_set()
# - dataset.annotation_set = dataset.upload_annotation_set()
# - dataset.annotation_set.task

# %%
data_handle = Dataset.prepare_data("pytorch")

# %% [markdown]
# - Dataset = collection of images
# - Image = raw data, and annotation
#
# - Annotation = meta data on an image
# - Annotation set = collection of annotations for all images in a Dataset

# %%
sdk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b90427c0f679> in <module>()
# ----> 1 sdk
#
# NameError: name 'sdk' is not defined

# %%
class Image:
    id = None
    dataset = None
    path_to_image = None
    

class Dataset:
    
    images = []
    
    def initiliase_images(self, path_to_images):
        
        for i_image:
            i_path = 
            
            new_image = Image(i_path)
            images.append(new_image)

# %%
   
class Image:
    id = None
    dataset = None
    annotation_sets = None
    annotations = None
    path_to_image = None

    def annotation_sets(self) -> [AnnotationSet]:
        pass

    def annotations(self, annotation_set: AnnotationSet = None) -> [Annotation]:
        if annotation_set:
            return annotation_set.annotations(images=self)

        return api.get_annotations(dataset_id=self.dataset.id, image_ids=[self.id])


class Dataset:
    """Summary of class here.

    Longer class information....
    Longer class information....

    Attributes:
        images: A list of all the images inside Dataset
        
        
    Methods:
        add_data
    
    """
    
    images = []
    
       id = None
        
    def __init__(self, sdk, **kwargs):
        
        self.sdk = sdk
        self.id = kwargs.get('id')
        self.name = kwargs.get('name')
        
        self.annotation_sets = kwargs.get('annotation_sets')
        self.is_public = kwargs.get('is_public')
        self.license = kwargs.get('license')
        self.images = []
        
    #    self.total_classes = kwargs.get('total_classes')
  #      self.created_at = kwargs.get('created_at')
  #      self.users_shared = kwargs.get('users_shared')
     #   self.top3_classes = kwargs.get('top3_classes')    
  #      self.total_annotation_objects = kwargs.get('total_annotation_objects')


#    def images(self, classes=None, tags=None, task=None) -> [Image]:
 #       pass
    
    def images(self, folder_id = None, **kwargs):
        return self.sdk.list_dataset_contents(self.id, folder_id, **kwargs)
    
    def annotation_sets(self) -> [AnnotationSet]:
        pass

    def annotations(self, annotation_set: AnnotationSet = None) -> [Annotation]:
        if annotation_set:
            return annotation_set.annotations()

        return api.get_annotations(dataset_id=self.id)
    
    def __repr__(self):
        return "Dataset {} - '{}'".format(self.id, self.name)
    
    def __str__(self):
        return 'Dataset (id={}, name={})'.format(self.id, self.name)
   

    def add_data(self, files=[], urls=[], annotation_task=None, folder_id=None):
        """Adds images and optionally annotations to a Dataset

        Longer Description

        Args:
            files: 
            urls: 
            annotation_task: 
            folder_id:
            
        Returns:


        Raises:

        """
        return self.sdk.upload_dataset(self.id, files, urls, annotation_task, folder_id)

    def update(self):
        """Updates the datataset to reflect any addition done via UI
        """
        
        dataset = self.sdk.get_dataset(self.id)
        self.__dict__.update(dataset.__dict__)

    def browse(self):
        utils.browse(self.sdk.ui.dataset_url(self.id))

    def annotate(self):
        # TODO: select by annotation task
        if len(self.annotation_sets) > 0:
            utils.browse(self.sdk.ui.annotate_url(self.annotation_sets[0]))
        else:
            print("No annotation sets in dataset " + self.name)



    def search(self, **kwargs):
        pass
